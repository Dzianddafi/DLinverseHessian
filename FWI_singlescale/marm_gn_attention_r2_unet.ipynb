# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
sys.path.append('/home/jovyan/work')

import logging
import segyio
import numpy as np
import matplotlib.pyplot as plt
import torch
import time
import gc
from tqdm.notebook import tqdm

from scipy.ndimage import gaussian_filter
from scipy.optimize import minimize
from scipy.signal import butter, sosfilt
from devito import *
from copy import deepcopy
from distributed import Client, wait, LocalCluster

from examples.seismic import AcquisitionGeometry
from examples.seismic.acoustic import AcousticWaveSolver

from devito_ta.model_geom import get_model, get_geometry, grad_utils
from devito_ta.prepro import Filter, filter_data, CustomSource
from devito_ta.simulation_born import fm_multi_shots, grad_multi_shots, born_multi_shots, normalize
from devito_ta.prepro_dl import train, prepare_data
from devito_ta.plotting import plot_shotrecord_cust, plot_velocity_cust, plot_acquisition_geometry, plot_freq
from deeplearning_ta.attention_r2_unet import *

configuration['log-level'] = 'WARNING'
configuration['opt'] = 'advanced'
logging.getLogger('distributed.nanny').setLevel(logging.ERROR)

# %%
file = 'vp_marmousi-ii_10m.segy'

with segyio.open(file, "r", ignore_geometry=True) as ss:
    n_traces = ss.tracecount
    sample_rate = segyio.tools.dt(ss) / 1000
    n_samples =ss.samples.size
    twt = ss.samples
    data = ss.trace.raw[:]

# %%
# Define water bottom depth in grid
wb = 50

# Define the model
v = data[200:1300, wb:].copy()             # Remove water layer

# Add water bottom to initial model
water_btm = np.ones((v.shape[0], wb)) * 1.5
v = np.concatenate([water_btm, v], axis=1)

# Create initial model
init = gaussian_filter(v, sigma=[20, 20])  
init[:, :wb] = water_btm

init = np.clip(init, a_min=1.5, a_max=4.5)

# Get model
shape = (1100, 351)
spacing = (10, 10)
origin = (0, 0)

model1 = get_model(np.clip(v, 1.5, 5), shape, spacing, origin)
model0 = get_model(init, shape, spacing, origin)

# Plot velocity model
plot_velocity_cust(model1, colorbar=True, save=False, title='True Model', name='true_model')
plot_velocity_cust(model0, colorbar=True, save=False, title='Initial Model', name='init_model')

# %%
model1.critical_dt
# Out:
# np.float32(1.18)

# %%
# Create new geometry for 50 shots
par = {'nx':1100,          'dx':10,       'ox':0,
       'nz':351,          'dz':10,       'oz':0,
       'ns':30,           'ds':300,      'os':2020.0,  'sz':0,
       'nr':200,          'dr':10.0,     'or':0,       'rz':0,
       'nt':4000,         'dt':1.18,        'ot':0,       'nof':20,
       'freq':5,
      }

# Sampling frequency
fs = 1 / (par['dt']/1000)
nbl = model1.nbl

# Axes
x = np.arange(par['nx']) * par['dx'] + par['ox']
z = np.arange(par['nz']) * par['dz'] + par['oz']
t = np.arange(par['nt']) * par['dt'] + par['ot']
tmax = t[-1]

# Sources
x_s = np.zeros((par['ns'], 2))
x_s[:, 0] = np.arange(par['ns']) * par['ds'] + par['os']
x_s[:, 1] = par['sz'] 

# Receivers
x_r = np.zeros((par['nr'], 2))
x_r[:, 0] = np.arange(par['nr']) * par['dr'] + par['or']
x_r[:, 1] = par['rz'] 

geometry1 = get_geometry(model=model1,
                         src_x=x_s[:, 0],
                         src_z=x_s[:, 1],
                         rec_x=x_r[:, 0],
                         rec_z=x_r[:, 1],
                         t0=0,
                         tn=par['nt'],
                         nof=par['nof'],
                         src_type='Ricker',
                         f0=par['freq']/1000,
                         dt=par['dt'])


n_workers = 6

cluster = LocalCluster(
    n_workers=n_workers,
    memory_limit='auto',
    threads_per_worker=4,
    death_timeout=3600
)

client = Client(cluster)
client.restart()
# Out:
# 2025-10-13 19:52:45,637 - distributed.process - WARNING - [<AsyncProcess Dask Worker process (from Nanny)>] process 31601 exit status was already read will report exitcode 255

# %%
plot_acquisition_geometry(geometry1, 'Acquisition Geometry')

# %%
# Perform forward modelling at 10 Hz
dt = par['dt']

start_10hz = time.time()
fm = fm_multi_shots(model1, geometry1, n_workers, client, dt=dt)
finish_10hz = time.time()

duration_10hz = finish_10hz - start_10hz
print(f'Forward modelling duration for 30 shots: {(duration_10hz/60):.2f} minutes')
# Out:
# Operator `Forward` ran in 1.52 s
# Operator `Forward` ran in 1.56 s
# Operator `Forward` ran in 1.71 s
# Operator `Forward` ran in 1.51 s
# Operator `Forward` ran in 1.64 s
# Operator `Forward` ran in 1.64 s
# Operator `Forward` ran in 1.46 s
# Operator `Forward` ran in 1.48 s
# Operator `Forward` ran in 1.55 s
# Operator `Forward` ran in 1.43 s
# Operator `Forward` ran in 1.53 s
# Operator `Forward` ran in 1.54 s
# Operator `Forward` ran in 1.44 s
# Operator `Forward` ran in 1.58 s
# Operator `Forward` ran in 1.62 s
# Operator `Forward` ran in 1.49 s
# Operator `Forward` ran in 1.43 s
# Operator `Forward` ran in 1.60 s
# Operator `Forward` ran in 1.43 s
# Operator `Forward` ran in 1.57 s
# Operator `Forward` ran in 1.52 s
# Operator `Forward` ran in 1.60 s
# Operator `Forward` ran in 1.55 s
# Operator `Forward` ran in 1.89 s
# Operator `Forward` ran in 1.51 s
# Operator `Forward` ran in 1.47 s
# Operator `Forward` ran in 1.51 s
# Operator `Forward` ran in 1.55 s
# Operator `Forward` ran in 1.61 s
# Operator `Forward` ran in 1.49 s
# Forward modelling duration for 30 shots: 0.31 minutes

# %%
# Make sure dt is match
assert geometry1[0].dt == model1.critical_dt == dt == par['dt']

# %%
# Run born fwi

# Create initial guess model for inversion by smoothing the true model
model_up = torch.tensor(model0.vp.data[nbl:-nbl, nbl:-nbl]).T
model_tr = torch.tensor(model1.vp.data[nbl:-nbl, nbl:-nbl]).T
scat = torch.zeros_like(model_up)

# Store to GPU
device = 'cuda'
model_up = model_up.clone().to(device)
model_tr = model_tr.clone().to(device)
model_up.requires_grad = True
model_tr.requires_grad = True
scat.requires_grad = True

msk = torch.ones_like(torch.Tensor(model_up))
msk[:50] = 0
#msk = msk.to(device)

depth = torch.tensor(list(range(0, 351))*1100).reshape(1100, 351).T /351
first_ep, eps = 50, 5

# Set up params
device='cuda'
network = AttentionR2UNet(n_channels=2, n_classes=1, hidden_channels=64).to(device)
optimizer = torch.optim.Adam(network.parameters(), lr=1e-3)
optimizer_fwi = torch.optim.SGD([{'params': [model_up], 'lr': 1e2,}])
loss_fn = torch.nn.MSELoss()

# Set up FWI loss function
fpath = 'model_progress/marm_gn_attention_r2_unet'
def loss_fn_fwi(model_true, model_init, geoms, d_true, n_workers, client):

    # Set initial and true model as devito object
    model_true = get_model(model_true.detach().cpu().numpy(), shape, spacing, origin)
    model_init = get_model(model_init.detach().cpu().numpy(), shape, spacing, origin)
    

    loss, grad = grad_multi_shots(model_true, model_init, geoms, n_workers, client, d_true)
    client.restart(wait_for_workers=False)
    
    return loss, torch.tensor(grad).T

def born_fn_fwi(model_true, model_back, model_scat, geoms, n_workers, client):
    # Set initial, true, and scat model as devito object
    model_true = get_model(model_true.detach().cpu().numpy(), shape, spacing, origin)
    model_back = get_model(model_back.detach().cpu().numpy(), shape, spacing, origin)
    
    _, dm1 = born_multi_shots(model_true, model_back, model_scat, geoms, n_workers, client)
    client.restart()
    
    return torch.tensor(dm1).T

# %%
geoms = geometry1.copy()
d_true = [d for d, _ in fm]

#client.restart()

grads, dm1s, ngrads, dms, ups = [], [], [], [], []
data_loss, vel_loss, network_loss = [], [], []
FWI_itr = 50

strt = time.time()
for itr in range(FWI_itr):

    # compute the velocity difference
    vel_loss.append(loss_fn(model_up, model_tr).item())
    print(f'Iteration {itr+1}: velocity loss = {vel_loss[-1]}')

    # compute the FWI gradient and the data misfit
    loss, grad = loss_fn_fwi(model_tr.T, model_up.T, geoms, d_true, n_workers, client)
    print(f'Iteration {itr+1}: data loss = {loss}')
    data_loss.append(loss)

    # Normalize by the maximum of the first gradient and mask the shallow part
    gmax = torch.abs(grad).max()
    grad *= msk.detach().cpu()
    grad /= torch.Tensor(gmax)

    # compute the remigrated image from the gradient
    scat_model = grad_utils(model1, geometry1[0])[0]
    scat_model.data[nbl:-nbl, nbl:-nbl] = grad.T
    dm1 = born_fn_fwi(model_tr.T, model_up.T, scat_model, geoms, n_workers, client)

    # Normalize by the maximum and mask the shallow part
    dm1max = torch.abs(dm1).max()
    dm1 *= msk.detach().cpu()
    dm1 /= dm1max

    # Create training data for the network to learn the inverse of the Hessian
    assert dm1.shape == depth.shape == grad.shape == msk.shape
    dataloader = prepare_data(torch.Tensor(dm1), depth, torch.Tensor((grad/1e1)), patch_size=64, slide=16, batch_size=64)
    
    # Train the network
    epochs = first_ep if itr == 0 else eps
    
    network.train()
    for ep in tqdm(range(epochs)):
        running_loss = 0
        for sample in dataloader:
            optimizer.zero_grad()
            
            x1, y1 = sample[0].to(device), sample[1].unsqueeze(1).to(device)
            dm_pred = network(x1)
            
            loss_ = loss_fn(dm_pred, y1)
            running_loss += loss_.item()

            loss_.backward()
            optimizer.step()

        network_loss.append(running_loss/len(dataloader))
        print(f'Training Epoch {ep}, Loss = {running_loss/len(dataloader)}')

    # Apply the network to the FWI gradient to get the Hessian corrected update 
    dm1 = torch.Tensor(dm1).to(device)
    depth = depth.to(device)
    grad = torch.Tensor(grad).to(device)

    with torch.no_grad():
        inpg = torch.cat([dm1.unsqueeze(0), depth.unsqueeze(0)]).float().to(device)
        g = network(inpg.unsqueeze(0)).squeeze() * msk.to(device)

        inpdm = torch.cat([grad.unsqueeze(0), depth.unsqueeze(0)]).float().to(device)
        dm = network(inpdm.unsqueeze(0)).squeeze() * msk.to(device)
    
    # Update model
    if itr == 0:
        model_up = model_up - dm
        ups.append(model_up.detach().cpu().numpy())     
    elif itr != 0 and vel_loss[-1] <= vel_loss[-2]:
        model_up = model_up - dm
        ups.append(model_up.detach().cpu().numpy())
    
    if itr == 0:
        np.savetxt(f'{fpath}/first_grad.txt', grad.detach().cpu().numpy())
        np.savetxt(f'{fpath}/first_dm1.txt', dm1.detach().cpu().numpy())
        np.savetxt(f'{fpath}/first_g.txt', g.detach().cpu().numpy())
        np.savetxt(f'{fpath}/first_dm.txt', dm.detach().cpu().numpy())
        np.savetxt(f'{fpath}/first_model.txt', model_up.detach().cpu().numpy())
    else:
        np.savetxt(f'{fpath}/grad_monitor.txt', grad.detach().cpu().numpy())
        np.savetxt(f'{fpath}/dm1_monitor.txt', dm1.detach().cpu().numpy())
        np.savetxt(f'{fpath}/g_monitor.txt', g.detach().cpu().numpy())
        np.savetxt(f'{fpath}/dm_monitor.txt', dm.detach().cpu().numpy())
        np.savetxt(f'{fpath}/model_monitor.txt', model_up.detach().cpu().numpy())
        np.savetxt(f'{fpath}/loss_monitor.txt', data_loss)
    
    del dataloader
    gc.collect()
    torch.cuda.empty_cache()
fnsh = time.time()
# Out:
# Iteration 1: velocity loss = 0.125953808426857
# /home/jovyan/work/devito_ta/simulation_born.py:111: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 1.96 s
# Operator `Forward` ran in 1.85 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 1.80 s
# Operator `Forward` ran in 1.93 s
# Operator `Forward` ran in 1.67 s
# Operator `Gradient` ran in 2.68 s
# Operator `Gradient` ran in 2.63 s
# Operator `Gradient` ran in 2.78 s
# Operator `Gradient` ran in 2.62 s
# Operator `Gradient` ran in 3.09 s
# Operator `Gradient` ran in 2.93 s
# 2025-10-13 15:44:37,135 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.00 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 15:44:37,351 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.04 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 15:44:37,641 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.99 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 15:44:37,741 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.00 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 15:44:37,754 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.99 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 15:44:37,860 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.04 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.82 s
# Operator `Forward` ran in 1.86 s
# Operator `Forward` ran in 1.83 s
# Operator `Forward` ran in 1.77 s
# Operator `Forward` ran in 1.83 s
# Operator `Forward` ran in 2.08 s
# Operator `Gradient` ran in 2.57 s
# Operator `Gradient` ran in 2.59 s
# Operator `Gradient` ran in 2.73 s
# Operator `Gradient` ran in 2.42 s
# Operator `Gradient` ran in 2.73 s
# Operator `Gradient` ran in 4.11 s
# Operator `Forward` ran in 1.87 s
# Operator `Forward` ran in 1.99 s
# Operator `Forward` ran in 1.98 s
# Operator `Forward` ran in 1.89 s
# Operator `Forward` ran in 2.02 s
# Operator `Forward` ran in 4.40 s
# Operator `Gradient` ran in 2.98 s
# Operator `Gradient` ran in 2.92 s
# Operator `Gradient` ran in 2.75 s
# Operator `Gradient` ran in 2.72 s
# Operator `Gradient` ran in 2.83 s
# Operator `Gradient` ran in 5.04 s
# Operator `Forward` ran in 1.95 s
# Operator `Forward` ran in 1.97 s
# Operator `Forward` ran in 1.81 s
# Operator `Forward` ran in 1.98 s
# Operator `Forward` ran in 1.91 s
# Operator `Forward` ran in 2.03 s
# Operator `Gradient` ran in 2.70 s
# Operator `Gradient` ran in 2.74 s
# Operator `Gradient` ran in 2.78 s
# Operator `Gradient` ran in 2.79 s
# Operator `Gradient` ran in 3.10 s
# Operator `Gradient` ran in 2.72 s
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 1.80 s
# Operator `Forward` ran in 1.67 s
# Operator `Forward` ran in 1.64 s
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 1.80 s
# Operator `Gradient` ran in 2.72 s
# Operator `Gradient` ran in 2.64 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 2.73 s
# Operator `Gradient` ran in 2.87 s
# Operator `Gradient` ran in 5.67 s
# Iteration 1: data loss = 218953.90625
# /home/jovyan/work/devito_ta/simulation_born.py:188: UserWarning: Sending large graph of size 11.85 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(born_x_shot, model_true,
# Operator `Forward` ran in 2.13 s
# Operator `Forward` ran in 2.15 s
# Operator `Forward` ran in 2.28 s
# Operator `Forward` ran in 2.06 s
# Operator `Forward` ran in 2.35 s
# Operator `Born` ran in 3.63 s
# Operator `Born` ran in 3.72 s
# Operator `Born` ran in 4.21 s
# Operator `Born` ran in 4.06 s
# Operator `Born` ran in 4.40 s
# Operator `Forward` ran in 8.73 s
# Operator `Gradient` ran in 3.28 s
# Operator `Gradient` ran in 3.17 s
# Operator `Gradient` ran in 5.27 s
# Operator `Gradient` ran in 5.38 s
# Operator `Gradient` ran in 5.65 s
# Operator `Born` ran in 3.96 s
# Operator `Gradient` ran in 5.37 s
# Operator `Forward` ran in 2.13 s
# Operator `Forward` ran in 1.82 s
# Operator `Forward` ran in 1.99 s
# Operator `Forward` ran in 2.21 s
# Operator `Forward` ran in 2.46 s
# Operator `Born` ran in 3.70 s
# Operator `Born` ran in 3.98 s
# Operator `Born` ran in 3.63 s
# Operator `Born` ran in 4.24 s
# Operator `Born` ran in 4.49 s
# Operator `Forward` ran in 8.27 s
# Operator `Gradient` ran in 3.25 s
# Operator `Gradient` ran in 3.17 s
# Operator `Gradient` ran in 3.51 s
# Operator `Gradient` ran in 3.40 s
# Operator `Gradient` ran in 4.14 s
# Operator `Born` ran in 4.01 s
# Operator `Gradient` ran in 9.92 s
# 2025-10-13 15:46:42,148 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.94 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 15:46:42,316 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.99 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 15:46:42,516 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.04 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.68 s
# Operator `Forward` ran in 1.71 s
# Operator `Forward` ran in 2.15 s
# Operator `Forward` ran in 1.68 s
# Operator `Forward` ran in 2.16 s
# Operator `Forward` ran in 2.06 s
# Operator `Born` ran in 4.12 s
# Operator `Born` ran in 3.57 s
# Operator `Born` ran in 4.27 s
# Operator `Born` ran in 3.71 s
# Operator `Born` ran in 3.84 s
# Operator `Born` ran in 4.21 s
# Operator `Gradient` ran in 2.67 s
# Operator `Gradient` ran in 3.25 s
# Operator `Gradient` ran in 3.16 s
# Operator `Gradient` ran in 3.10 s
# Operator `Gradient` ran in 3.27 s
# Operator `Gradient` ran in 3.68 s
# Operator `Forward` ran in 1.66 s
# Operator `Forward` ran in 1.83 s
# Operator `Forward` ran in 2.15 s
# Operator `Forward` ran in 2.09 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 2.06 s
# Operator `Born` ran in 4.10 s
# Operator `Born` ran in 3.85 s
# Operator `Born` ran in 3.94 s
# Operator `Born` ran in 4.56 s
# Operator `Born` ran in 3.85 s
# Operator `Born` ran in 4.55 s
# Operator `Gradient` ran in 2.87 s
# Operator `Gradient` ran in 3.20 s
# Operator `Gradient` ran in 3.41 s
# Operator `Gradient` ran in 3.17 s
# Operator `Gradient` ran in 3.09 s
# Operator `Gradient` ran in 3.46 s
# Operator `Forward` ran in 1.61 s
# Operator `Forward` ran in 1.79 s
# Operator `Forward` ran in 1.85 s
# Operator `Forward` ran in 1.88 s
# Operator `Forward` ran in 2.03 s
# Operator `Forward` ran in 1.99 s
# Operator `Born` ran in 3.64 s
# Operator `Born` ran in 3.95 s
# Operator `Born` ran in 4.03 s
# Operator `Born` ran in 3.98 s
# Operator `Born` ran in 4.69 s
# Operator `Born` ran in 4.66 s
# Operator `Gradient` ran in 2.82 s
# Operator `Gradient` ran in 2.84 s
# Operator `Gradient` ran in 3.07 s
# Operator `Gradient` ran in 2.90 s
# Operator `Gradient` ran in 3.12 s
# Operator `Gradient` ran in 3.73 s
#   0%|          | 0/50 [00:00<?, ?it/s]
# Training Epoch 0, Loss = 0.0015032455945966977
# Training Epoch 1, Loss = 2.922483168054871e-05
# Training Epoch 2, Loss = 2.3237671342033913e-05
# Training Epoch 3, Loss = 2.172390987519286e-05
# Training Epoch 4, Loss = 2.4346833102356995e-05
# Training Epoch 5, Loss = 1.883944434927516e-05
# Training Epoch 6, Loss = 1.7206141838394448e-05
# Training Epoch 7, Loss = 1.4838895867331352e-05
# Training Epoch 8, Loss = 1.4858134688124929e-05
# Training Epoch 9, Loss = 1.3705263047005485e-05
# Training Epoch 10, Loss = 1.5226886698221445e-05
# Training Epoch 11, Loss = 1.4154335225450746e-05
# Training Epoch 12, Loss = 1.2252842152334072e-05
# Training Epoch 13, Loss = 1.173717764251873e-05
# Training Epoch 14, Loss = 1.3478710032222652e-05
# Training Epoch 15, Loss = 1.029768537334097e-05
# Training Epoch 16, Loss = 9.708633146264849e-06
# Training Epoch 17, Loss = 9.029057412251847e-06
# Training Epoch 18, Loss = 6.773934329824849e-06
# Training Epoch 19, Loss = 6.3191511066669816e-06
# Training Epoch 20, Loss = 5.194034599947654e-06
# Training Epoch 21, Loss = 4.923523477500504e-06
# Training Epoch 22, Loss = 6.053971848019755e-06
# Training Epoch 23, Loss = 4.558982973414812e-06
# Training Epoch 24, Loss = 4.211761220316097e-06
# Training Epoch 25, Loss = 7.598544972274375e-06
# Training Epoch 26, Loss = 5.721171558189213e-06
# Training Epoch 27, Loss = 3.971476903628114e-06
# Training Epoch 28, Loss = 4.616115657375927e-06
# Training Epoch 29, Loss = 3.3650433089500524e-06
# Training Epoch 30, Loss = 2.791844335412827e-06
# Training Epoch 31, Loss = 2.693470532717785e-06
# Training Epoch 32, Loss = 3.0447619843756907e-06
# Training Epoch 33, Loss = 3.5201672828543605e-06
# Training Epoch 34, Loss = 3.819554404076169e-05
# Training Epoch 35, Loss = 1.4255699570888316e-05
# Training Epoch 36, Loss = 1.2454889811714079e-05
# Training Epoch 37, Loss = 1.1305806420896634e-05
# Training Epoch 38, Loss = 1.0492427555329954e-05
# Training Epoch 39, Loss = 9.821030188576058e-06
# Training Epoch 40, Loss = 1.0377679540608445e-05
# Training Epoch 41, Loss = 8.804672676295124e-06
# Training Epoch 42, Loss = 8.683213937844157e-06
# Training Epoch 43, Loss = 7.91985002354184e-06
# Training Epoch 44, Loss = 7.412594509286287e-06
# Training Epoch 45, Loss = 7.046088795899275e-06
# Training Epoch 46, Loss = 6.491659107591612e-06
# Training Epoch 47, Loss = 5.935319329862468e-06
# Training Epoch 48, Loss = 5.4581501797085375e-06
# Training Epoch 49, Loss = 5.516625654218864e-06
# Iteration 2: velocity loss = 0.12245355546474457
# /home/jovyan/work/devito_ta/simulation_born.py:111: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 1.97 s
# Operator `Forward` ran in 2.20 s
# Operator `Forward` ran in 1.99 s
# Operator `Forward` ran in 2.04 s
# Operator `Forward` ran in 2.26 s
# Operator `Forward` ran in 1.99 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 2.77 s
# Operator `Gradient` ran in 2.82 s
# Operator `Gradient` ran in 2.96 s
# Operator `Gradient` ran in 3.11 s
# Operator `Gradient` ran in 3.48 s
# 2025-10-13 16:11:32,835 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.08 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:11:32,873 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.95 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:11:32,950 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.97 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:11:32,986 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.96 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:11:33,098 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.07 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:11:33,187 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.03 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.64 s
# Operator `Forward` ran in 1.70 s
# Operator `Forward` ran in 1.63 s
# Operator `Forward` ran in 1.60 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 4.90 s
# Operator `Gradient` ran in 2.50 s
# Operator `Gradient` ran in 2.48 s
# Operator `Gradient` ran in 2.54 s
# Operator `Gradient` ran in 3.37 s
# Operator `Gradient` ran in 4.15 s
# Operator `Gradient` ran in 3.66 s
# Operator `Forward` ran in 1.87 s
# Operator `Forward` ran in 1.60 s
# Operator `Forward` ran in 2.07 s
# Operator `Forward` ran in 1.70 s
# Operator `Forward` ran in 4.74 s
# Operator `Gradient` ran in 2.52 s
# Operator `Gradient` ran in 2.65 s
# Operator `Forward` ran in 5.74 s
# Operator `Gradient` ran in 3.02 s
# Operator `Gradient` ran in 2.77 s
# Operator `Gradient` ran in 3.18 s
# Operator `Gradient` ran in 3.35 s
# Operator `Forward` ran in 1.68 s
# Operator `Forward` ran in 1.90 s
# Operator `Forward` ran in 2.05 s
# Operator `Forward` ran in 1.92 s
# Operator `Forward` ran in 2.02 s
# Operator `Gradient` ran in 2.62 s
# Operator `Forward` ran in 4.17 s
# Operator `Gradient` ran in 2.69 s
# Operator `Gradient` ran in 2.76 s
# Operator `Gradient` ran in 2.83 s
# Operator `Gradient` ran in 4.64 s
# Operator `Gradient` ran in 4.61 s
# Operator `Forward` ran in 1.80 s
# Operator `Forward` ran in 1.68 s
# Operator `Forward` ran in 1.79 s
# Operator `Forward` ran in 1.83 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 1.96 s
# Operator `Gradient` ran in 2.74 s
# Operator `Gradient` ran in 2.55 s
# Operator `Gradient` ran in 2.81 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 2.90 s
# Operator `Gradient` ran in 2.93 s
# Iteration 2: data loss = 171886.59375
# /home/jovyan/work/devito_ta/simulation_born.py:188: UserWarning: Sending large graph of size 11.85 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(born_x_shot, model_true,
# Operator `Forward` ran in 2.28 s
# Operator `Forward` ran in 2.31 s
# Operator `Forward` ran in 2.07 s
# Operator `Forward` ran in 2.01 s
# Operator `Born` ran in 3.65 s
# Operator `Born` ran in 3.70 s
# Operator `Forward` ran in 7.34 s
# Operator `Born` ran in 4.39 s
# Operator `Born` ran in 4.86 s
# Operator `Gradient` ran in 3.28 s
# Operator `Forward` ran in 10.63 s
# Operator `Gradient` ran in 3.21 s
# Operator `Born` ran in 3.85 s
# Operator `Gradient` ran in 5.24 s
# Operator `Born` ran in 3.66 s
# Operator `Gradient` ran in 8.49 s
# Operator `Gradient` ran in 5.48 s
# Operator `Gradient` ran in 5.65 s
# Operator `Forward` ran in 1.72 s
# Operator `Forward` ran in 2.01 s
# Operator `Forward` ran in 1.71 s
# Operator `Forward` ran in 2.02 s
# Operator `Forward` ran in 2.08 s
# Operator `Forward` ran in 3.75 s
# Operator `Born` ran in 3.71 s
# Operator `Born` ran in 4.44 s
# Operator `Born` ran in 4.65 s
# Operator `Born` ran in 4.66 s
# Operator `Born` ran in 4.53 s
# Operator `Born` ran in 3.66 s
# Operator `Gradient` ran in 3.25 s
# Operator `Gradient` ran in 3.29 s
# Operator `Gradient` ran in 3.42 s
# Operator `Gradient` ran in 3.58 s
# Operator `Gradient` ran in 3.76 s
# Operator `Gradient` ran in 4.81 s
# 2025-10-13 16:13:29,931 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.08 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:13:30,340 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.01 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:13:30,435 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.11 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.68 s
# Operator `Forward` ran in 1.66 s
# Operator `Forward` ran in 1.69 s
# Operator `Forward` ran in 2.03 s
# Operator `Forward` ran in 2.46 s
# Operator `Forward` ran in 2.28 s
# Operator `Born` ran in 3.68 s
# Operator `Born` ran in 3.71 s
# Operator `Born` ran in 3.73 s
# Operator `Born` ran in 5.38 s
# Operator `Born` ran in 3.73 s
# Operator `Born` ran in 4.42 s
# Operator `Gradient` ran in 2.47 s
# Operator `Gradient` ran in 2.62 s
# Operator `Gradient` ran in 2.95 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 3.79 s
# Operator `Gradient` ran in 3.89 s
# Operator `Forward` ran in 1.68 s
# Operator `Forward` ran in 1.96 s
# Operator `Forward` ran in 1.68 s
# Operator `Forward` ran in 1.86 s
# Operator `Forward` ran in 1.94 s
# Operator `Forward` ran in 1.90 s
# Operator `Born` ran in 3.64 s
# Operator `Born` ran in 3.69 s
# Operator `Born` ran in 3.76 s
# Operator `Born` ran in 3.87 s
# Operator `Born` ran in 4.18 s
# Operator `Born` ran in 5.48 s
# Operator `Gradient` ran in 2.93 s
# Operator `Gradient` ran in 2.86 s
# Operator `Gradient` ran in 3.01 s
# Operator `Gradient` ran in 3.09 s
# Operator `Gradient` ran in 3.40 s
# Operator `Gradient` ran in 3.02 s
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 1.80 s
# Operator `Forward` ran in 1.64 s
# Operator `Forward` ran in 1.88 s
# Operator `Forward` ran in 1.99 s
# Operator `Forward` ran in 1.92 s
# Operator `Born` ran in 3.76 s
# Operator `Born` ran in 3.64 s
# Operator `Born` ran in 3.69 s
# Operator `Born` ran in 3.66 s
# Operator `Born` ran in 3.75 s
# Operator `Born` ran in 3.92 s
# Operator `Gradient` ran in 2.69 s
# Operator `Gradient` ran in 3.10 s
# Operator `Gradient` ran in 3.18 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 2.81 s
# Operator `Gradient` ran in 3.14 s
#   0%|          | 0/5 [00:00<?, ?it/s]
# Training Epoch 0, Loss = 1.0943785401051443e-05
# Training Epoch 1, Loss = 7.492122868133182e-05
# Training Epoch 2, Loss = 3.564742463894162e-05
# Training Epoch 3, Loss = 2.5336802347564e-05
# Training Epoch 4, Loss = 2.0054581732857288e-05
# Iteration 3: velocity loss = 0.11861401796340942
# /home/jovyan/work/devito_ta/simulation_born.py:111: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.01 s
# Operator `Forward` ran in 2.00 s
# Operator `Forward` ran in 2.04 s
# Operator `Forward` ran in 2.11 s
# Operator `Forward` ran in 2.04 s
# Operator `Gradient` ran in 2.71 s
# Operator `Gradient` ran in 2.85 s
# Operator `Gradient` ran in 2.89 s
# Operator `Forward` ran in 5.78 s
# Operator `Gradient` ran in 2.92 s
# Operator `Gradient` ran in 2.83 s
# Operator `Gradient` ran in 3.72 s
# 2025-10-13 16:17:11,101 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.02 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:17:11,175 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.04 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:17:11,305 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.98 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:17:11,309 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.08 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:17:11,638 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.10 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:17:11,701 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.03 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.64 s
# Operator `Forward` ran in 1.63 s
# Operator `Forward` ran in 1.72 s
# Operator `Forward` ran in 1.60 s
# Operator `Forward` ran in 2.49 s
# Operator `Forward` ran in 4.37 s
# Operator `Gradient` ran in 2.45 s
# Operator `Gradient` ran in 2.48 s
# Operator `Gradient` ran in 2.50 s
# Operator `Gradient` ran in 3.47 s
# Operator `Gradient` ran in 3.78 s
# Operator `Gradient` ran in 3.58 s
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 1.61 s
# Operator `Forward` ran in 1.69 s
# Operator `Forward` ran in 4.35 s
# Operator `Gradient` ran in 2.48 s
# Operator `Forward` ran in 4.75 s
# Operator `Gradient` ran in 2.48 s
# Operator `Gradient` ran in 2.51 s
# Operator `Forward` ran in 5.59 s
# Operator `Gradient` ran in 2.47 s
# Operator `Gradient` ran in 3.75 s
# Operator `Gradient` ran in 5.65 s
# Operator `Forward` ran in 1.96 s
# Operator `Forward` ran in 1.97 s
# Operator `Forward` ran in 1.98 s
# Operator `Forward` ran in 1.88 s
# Operator `Forward` ran in 1.81 s
# Operator `Forward` ran in 4.39 s
# Operator `Gradient` ran in 2.81 s
# Operator `Gradient` ran in 2.79 s
# Operator `Gradient` ran in 2.63 s
# Operator `Gradient` ran in 2.81 s
# Operator `Gradient` ran in 2.85 s
# Operator `Gradient` ran in 3.40 s
# Operator `Forward` ran in 1.66 s
# Operator `Forward` ran in 1.79 s
# Operator `Forward` ran in 1.84 s
# Operator `Forward` ran in 2.09 s
# Operator `Forward` ran in 2.10 s
# Operator `Forward` ran in 2.46 s
# Operator `Gradient` ran in 2.90 s
# Operator `Gradient` ran in 2.86 s
# Operator `Gradient` ran in 2.94 s
# Operator `Gradient` ran in 3.02 s
# Operator `Gradient` ran in 2.86 s
# Operator `Gradient` ran in 3.07 s
# Iteration 3: data loss = 134730.609375
# /home/jovyan/work/devito_ta/simulation_born.py:188: UserWarning: Sending large graph of size 11.85 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(born_x_shot, model_true,
# Operator `Forward` ran in 1.98 s
# Operator `Forward` ran in 2.04 s
# Operator `Forward` ran in 2.16 s
# Operator `Born` ran in 3.60 s
# Operator `Born` ran in 3.85 s
# Operator `Forward` ran in 6.30 s
# Operator `Born` ran in 4.26 s
# Operator `Gradient` ran in 3.09 s
# Operator `Born` ran in 3.79 s
# Operator `Gradient` ran in 4.68 s
# Operator `Forward` ran in 12.33 s
# Operator `Forward` ran in 13.91 s
# Operator `Gradient` ran in 5.50 s
# Operator `Born` ran in 3.61 s
# Operator `Gradient` ran in 4.65 s
# Operator `Born` ran in 3.80 s
# Operator `Gradient` ran in 5.41 s
# Operator `Gradient` ran in 6.45 s
# Operator `Forward` ran in 1.86 s
# Operator `Forward` ran in 1.93 s
# Operator `Forward` ran in 2.10 s
# Operator `Forward` ran in 2.31 s
# Operator `Forward` ran in 2.35 s
# Operator `Forward` ran in 2.67 s
# Operator `Born` ran in 3.86 s
# Operator `Born` ran in 3.72 s
# Operator `Born` ran in 3.73 s
# Operator `Born` ran in 3.65 s
# Operator `Born` ran in 4.58 s
# Operator `Born` ran in 5.66 s
# Operator `Gradient` ran in 2.92 s
# Operator `Gradient` ran in 3.38 s
# Operator `Gradient` ran in 3.29 s
# Operator `Gradient` ran in 3.78 s
# Operator `Gradient` ran in 4.06 s
# Operator `Gradient` ran in 4.23 s
# 2025-10-13 16:19:16,156 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.01 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:19:16,250 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.99 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:19:16,361 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.04 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 1.98 s
# Operator `Forward` ran in 1.66 s
# Operator `Forward` ran in 2.32 s
# Operator `Forward` ran in 1.95 s
# Operator `Forward` ran in 2.41 s
# Operator `Born` ran in 3.65 s
# Operator `Born` ran in 4.56 s
# Operator `Born` ran in 4.64 s
# Operator `Born` ran in 3.81 s
# Operator `Born` ran in 4.58 s
# Operator `Born` ran in 5.54 s
# Operator `Gradient` ran in 2.50 s
# Operator `Gradient` ran in 3.33 s
# Operator `Gradient` ran in 3.52 s
# Operator `Gradient` ran in 2.75 s
# Operator `Gradient` ran in 3.91 s
# Operator `Gradient` ran in 3.77 s
# Operator `Forward` ran in 1.64 s
# Operator `Forward` ran in 2.01 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 1.86 s
# Operator `Forward` ran in 5.31 s
# Operator `Forward` ran in 5.97 s
# Operator `Born` ran in 3.89 s
# Operator `Born` ran in 3.72 s
# Operator `Born` ran in 3.70 s
# Operator `Born` ran in 4.01 s
# Operator `Gradient` ran in 2.99 s
# Operator `Gradient` ran in 3.49 s
# Operator `Gradient` ran in 3.50 s
# Operator `Gradient` ran in 3.48 s
# Operator `Born` ran in 4.48 s
# Operator `Born` ran in 4.36 s
# Operator `Gradient` ran in 4.89 s
# Operator `Gradient` ran in 5.44 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 2.07 s
# Operator `Forward` ran in 1.80 s
# Operator `Forward` ran in 1.99 s
# Operator `Forward` ran in 2.40 s
# Operator `Forward` ran in 2.10 s
# Operator `Born` ran in 3.73 s
# Operator `Born` ran in 3.62 s
# Operator `Born` ran in 3.72 s
# Operator `Born` ran in 3.76 s
# Operator `Born` ran in 3.63 s
# Operator `Born` ran in 3.80 s
# Operator `Gradient` ran in 3.02 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 3.23 s
# Operator `Gradient` ran in 3.14 s
# Operator `Gradient` ran in 3.62 s
# Operator `Gradient` ran in 3.89 s
#   0%|          | 0/5 [00:00<?, ?it/s]
# Training Epoch 0, Loss = 3.118323446010079e-05
# Training Epoch 1, Loss = 2.13798701615846e-05
# Training Epoch 2, Loss = 1.6704135389000085e-05
# Training Epoch 3, Loss = 1.2623253223554187e-05
# Training Epoch 4, Loss = 1.0680126397719102e-05
# Iteration 4: velocity loss = 0.1119358092546463
# /home/jovyan/work/devito_ta/simulation_born.py:111: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 1.89 s
# Operator `Forward` ran in 2.29 s
# Operator `Forward` ran in 2.30 s
# Operator `Forward` ran in 2.05 s
# Operator `Forward` ran in 2.02 s
# Operator `Forward` ran in 4.58 s
# Operator `Gradient` ran in 2.78 s
# Operator `Gradient` ran in 2.84 s
# Operator `Gradient` ran in 3.24 s
# Operator `Gradient` ran in 3.25 s
# Operator `Gradient` ran in 2.93 s
# Operator `Gradient` ran in 4.40 s
# 2025-10-13 16:23:03,551 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.01 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:23:03,686 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.97 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:23:04,034 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.99 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:23:04,194 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.00 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:23:04,276 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.98 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:23:04,285 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.08 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.71 s
# Operator `Forward` ran in 1.63 s
# Operator `Forward` ran in 1.66 s
# Operator `Forward` ran in 1.67 s
# Operator `Forward` ran in 2.02 s
# Operator `Gradient` ran in 2.45 s
# Operator `Forward` ran in 4.75 s
# Operator `Gradient` ran in 2.55 s
# Operator `Gradient` ran in 2.67 s
# Operator `Gradient` ran in 3.10 s
# Operator `Gradient` ran in 3.46 s
# Operator `Gradient` ran in 8.02 s
# Operator `Forward` ran in 1.66 s
# Operator `Forward` ran in 1.68 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 4.45 s
# Operator `Forward` ran in 4.47 s
# Operator `Forward` ran in 4.48 s
# Operator `Gradient` ran in 2.60 s
# Operator `Gradient` ran in 2.50 s
# Operator `Gradient` ran in 2.83 s
# Operator `Gradient` ran in 3.07 s
# Operator `Gradient` ran in 3.58 s
# Operator `Gradient` ran in 3.84 s
# Operator `Forward` ran in 1.84 s
# Operator `Forward` ran in 1.72 s
# Operator `Forward` ran in 2.59 s
# Operator `Forward` ran in 2.41 s
# Operator `Forward` ran in 2.42 s
# Operator `Forward` ran in 3.69 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 2.76 s
# Operator `Gradient` ran in 3.15 s
# Operator `Gradient` ran in 3.08 s
# Operator `Gradient` ran in 3.12 s
# Operator `Gradient` ran in 3.40 s
# Operator `Forward` ran in 1.90 s
# Operator `Forward` ran in 1.89 s
# Operator `Forward` ran in 1.72 s
# Operator `Forward` ran in 1.92 s
# Operator `Forward` ran in 2.11 s
# Operator `Forward` ran in 3.02 s
# Operator `Gradient` ran in 2.76 s
# Operator `Gradient` ran in 2.74 s
# Operator `Gradient` ran in 2.74 s
# Operator `Gradient` ran in 3.01 s
# Operator `Gradient` ran in 3.10 s
# Operator `Gradient` ran in 3.11 s
# Iteration 4: data loss = 97713.703125
# /home/jovyan/work/devito_ta/simulation_born.py:188: UserWarning: Sending large graph of size 11.85 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(born_x_shot, model_true,
# Operator `Forward` ran in 2.07 s
# Operator `Forward` ran in 2.26 s
# Operator `Forward` ran in 2.19 s
# Operator `Forward` ran in 2.01 s
# Operator `Forward` ran in 2.29 s
# Operator `Born` ran in 3.71 s
# Operator `Born` ran in 4.13 s
# Operator `Born` ran in 4.08 s
# Operator `Born` ran in 4.55 s
# Operator `Forward` ran in 7.86 s
# Operator `Born` ran in 4.48 s
# Operator `Gradient` ran in 3.07 s
# Operator `Gradient` ran in 3.38 s
# Operator `Gradient` ran in 4.21 s
# Operator `Born` ran in 4.30 s
# Operator `Gradient` ran in 6.15 s
# Operator `Gradient` ran in 6.43 s
# Operator `Gradient` ran in 5.44 s
# Operator `Forward` ran in 2.02 s
# Operator `Forward` ran in 2.23 s
# Operator `Forward` ran in 2.20 s
# Operator `Forward` ran in 2.89 s
# Operator `Born` ran in 3.65 s
# Operator `Born` ran in 3.66 s
# Operator `Born` ran in 4.27 s
# Operator `Born` ran in 4.31 s
# Operator `Gradient` ran in 3.22 s
# Operator `Gradient` ran in 3.30 s
# Operator `Gradient` ran in 3.45 s
# Operator `Gradient` ran in 4.44 s
# Operator `Forward` ran in 12.73 s
# Operator `Forward` ran in 15.03 s
# Operator `Born` ran in 3.63 s
# Operator `Born` ran in 3.69 s
# Operator `Gradient` ran in 5.41 s
# Operator `Gradient` ran in 5.51 s
# Operator `Forward` ran in 1.79 s
# Operator `Forward` ran in 1.83 s
# Operator `Forward` ran in 1.90 s
# Operator `Forward` ran in 2.10 s
# Operator `Forward` ran in 2.36 s
# Operator `Forward` ran in 5.41 s
# Operator `Born` ran in 3.55 s
# Operator `Born` ran in 3.80 s
# Operator `Born` ran in 3.66 s
# Operator `Born` ran in 4.68 s
# Operator `Born` ran in 4.74 s
# Operator `Gradient` ran in 2.86 s
# Operator `Gradient` ran in 3.31 s
# Operator `Gradient` ran in 2.92 s
# Operator `Born` ran in 4.73 s
# Operator `Gradient` ran in 3.31 s
# Operator `Gradient` ran in 4.00 s
# Operator `Gradient` ran in 6.33 s
# Operator `Forward` ran in 1.88 s
# Operator `Forward` ran in 1.89 s
# Operator `Forward` ran in 2.18 s
# Operator `Forward` ran in 1.92 s
# Operator `Forward` ran in 2.16 s
# Operator `Forward` ran in 2.59 s
# Operator `Born` ran in 3.77 s
# Operator `Born` ran in 4.45 s
# Operator `Born` ran in 4.21 s
# Operator `Born` ran in 4.70 s
# Operator `Born` ran in 4.73 s
# Operator `Born` ran in 4.59 s
# Operator `Gradient` ran in 3.09 s
# Operator `Gradient` ran in 2.85 s
# Operator `Gradient` ran in 3.27 s
# Operator `Gradient` ran in 3.37 s
# Operator `Gradient` ran in 4.04 s
# Operator `Gradient` ran in 5.13 s
# Operator `Forward` ran in 2.04 s
# Operator `Forward` ran in 2.13 s
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 2.00 s
# Operator `Forward` ran in 2.89 s
# Operator `Born` ran in 3.73 s
# Operator `Born` ran in 4.49 s
# Operator `Born` ran in 4.62 s
# Operator `Born` ran in 4.59 s
# Operator `Born` ran in 4.03 s
# Operator `Born` ran in 5.70 s
# Operator `Gradient` ran in 3.61 s
# Operator `Gradient` ran in 3.28 s
# Operator `Gradient` ran in 3.56 s
# Operator `Gradient` ran in 3.60 s
# Operator `Gradient` ran in 3.88 s
# Operator `Gradient` ran in 3.53 s
#   0%|          | 0/5 [00:00<?, ?it/s]
# Training Epoch 0, Loss = 1.022907691260656e-05
# Training Epoch 1, Loss = 6.87628320172505e-06
# Training Epoch 2, Loss = 5.711829840115865e-06
# Training Epoch 3, Loss = 4.793065973424578e-06
# Training Epoch 4, Loss = 4.469473360617603e-06
# Iteration 5: velocity loss = 0.1053633987903595
# /home/jovyan/work/devito_ta/simulation_born.py:111: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.31 s
# Operator `Forward` ran in 2.04 s
# Operator `Forward` ran in 2.38 s
# Operator `Forward` ran in 2.25 s
# Operator `Forward` ran in 2.00 s
# Operator `Gradient` ran in 3.01 s
# Operator `Gradient` ran in 2.84 s
# Operator `Gradient` ran in 4.49 s
# Operator `Gradient` ran in 4.77 s
# Operator `Gradient` ran in 4.88 s
# Operator `Forward` ran in 11.95 s
# Operator `Gradient` ran in 5.21 s
# 2025-10-13 16:29:14,327 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.03 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:29:14,458 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.03 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:29:14,588 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.05 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:29:14,629 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.01 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:29:14,727 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.07 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 16:29:15,644 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.02 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.67 s
# Operator `Forward` ran in 1.98 s
# Operator `Forward` ran in 1.68 s
# Operator `Forward` ran in 3.24 s
# Operator `Forward` ran in 4.01 s
# Operator `Forward` ran in 4.28 s
# Operator `Gradient` ran in 3.31 s
# Operator `Gradient` ran in 3.67 s
# Operator `Gradient` ran in 5.14 s
# Operator `Gradient` ran in 3.79 s
# Operator `Gradient` ran in 5.19 s
# Operator `Gradient` ran in 4.22 s
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 1.67 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 1.79 s
# Operator `Forward` ran in 2.72 s
# Operator `Forward` ran in 2.95 s
# Operator `Gradient` ran in 2.48 s
# Operator `Gradient` ran in 2.87 s
# Operator `Gradient` ran in 3.35 s
# Operator `Gradient` ran in 3.23 s
# Operator `Gradient` ran in 3.84 s
# Operator `Gradient` ran in 3.68 s
# Operator `Forward` ran in 1.87 s
# Operator `Forward` ran in 1.98 s
# Operator `Forward` ran in 2.53 s
# Operator `Forward` ran in 2.40 s
# Operator `Forward` ran in 4.03 s
# Operator `Forward` ran in 4.48 s
# Operator `Gradient` ran in 2.82 s
# Operator `Gradient` ran in 2.75 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 3.50 s
# Operator `Gradient` ran in 3.31 s
# Operator `Gradient` ran in 3.08 s
# Operator `Forward` ran in 1.72 s
# Operator `Forward` ran in 1.91 s
# Operator `Forward` ran in 1.96 s
# Operator `Forward` ran in 2.41 s
# Operator `Forward` ran in 2.52 s
# Operator `Forward` ran in 2.65 s
# Operator `Gradient` ran in 2.82 s
# Operator `Gradient` ran in 2.80 s
# Operator `Gradient` ran in 2.80 s
# Operator `Gradient` ran in 3.08 s
# Operator `Gradient` ran in 2.99 s
# Operator `Gradient` ran in 3.18 s
# Iteration 5: data loss = 69470.6171875
# /home/jovyan/work/devito_ta/simulation_born.py:188: UserWarning: Sending large graph of size 11.85 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(born_x_shot, model_true,
# Operator `Forward` ran in 2.26 s
# Operator `Forward` ran in 1.84 s
# Operator `Forward` ran in 2.31 s
# Operator `Forward` ran in 2.06 s
# Operator `Forward` ran in 6.51 s
# Operator `Born` ran in 3.72 s
# Operator `Born` ran in 4.28 s
# Operator `Born` ran in 4.25 s
# Operator `Born` ran in 3.85 s
# Operator `Forward` ran in 8.11 s
# Operator `Gradient` ran in 3.64 s
# Operator `Gradient` ran in 3.45 s
# Operator `Born` ran in 4.57 s
# Operator `Born` ran in 3.62 s
# Operator `Gradient` ran in 4.86 s
# Operator `Gradient` ran in 5.79 s
# Operator `Gradient` ran in 5.35 s
# Operator `Gradient` ran in 6.88 s
# Operator `Forward` ran in 2.09 s
# Operator `Forward` ran in 1.67 s
# Operator `Forward` ran in 2.01 s
# Operator `Forward` ran in 2.00 s
# Operator `Forward` ran in 1.96 s
# Operator `Forward` ran in 2.13 s
# Operator `Born` ran in 3.61 s
# Operator `Born` ran in 3.70 s
# Operator `Born` ran in 3.71 s
# Operator `Born` ran in 3.61 s
# Operator `Born` ran in 3.69 s
# Operator `Born` ran in 3.94 s
# Operator `Gradient` ran in 3.27 s
# Operator `Gradient` ran in 3.15 s
# Operator `Gradient` ran in 3.19 s
# Operator `Gradient` ran in 3.15 s
# Operator `Gradient` ran in 3.22 s
# Operator `Gradient` ran in 3.31 s
# 2025-10-13 16:31:07,122 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.03 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.63 s
# Operator `Forward` ran in 1.97 s
# Operator `Forward` ran in 1.93 s
# Operator `Forward` ran in 1.80 s
# Operator `Forward` ran in 2.00 s
# Operator `Forward` ran in 2.39 s
# Operator `Born` ran in 3.70 s
# Operator `Born` ran in 3.67 s
# Operator `Born` ran in 4.47 s
# Operator `Born` ran in 3.59 s
# Operator `Born` ran in 4.17 s
# Operator `Born` ran in 4.42 s
# Operator `Gradient` ran in 2.74 s
# Operator `Gradient` ran in 3.25 s
# Operator `Gradient` ran in 3.03 s
# Operator `Gradient` ran in 2.98 s
# Operator `Gradient` ran in 2.90 s
# Operator `Gradient` ran in 3.93 s
# Operator `Forward` ran in 1.59 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 1.71 s
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 2.08 s
# Operator `Forward` ran in 4.38 s
# Operator `Born` ran in 3.61 s
# Operator `Born` ran in 3.71 s
# Operator `Born` ran in 3.68 s
# Operator `Born` ran in 4.08 s
# Operator `Born` ran in 3.67 s
# Operator `Gradient` ran in 3.07 s
# Operator `Gradient` ran in 2.85 s
# Operator `Born` ran in 3.73 s
# Operator `Gradient` ran in 2.92 s
# Operator `Gradient` ran in 2.90 s
# Operator `Gradient` ran in 3.41 s
# Operator `Gradient` ran in 5.12 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 2.36 s
# Operator `Forward` ran in 1.95 s
# Operator `Forward` ran in 2.09 s
# Operator `Forward` ran in 2.23 s
# Operator `Forward` ran in 2.47 s
# Operator `Born` ran in 3.95 s
# Operator `Born` ran in 4.11 s
# Operator `Born` ran in 4.01 s
# Operator `Born` ran in 3.72 s
# Operator `Born` ran in 4.67 s
# Operator `Born` ran in 4.60 s
# Operator `Gradient` ran in 3.14 s
# Operator `Gradient` ran in 3.20 s
# Operator `Gradient` ran in 3.24 s
# Operator `Gradient` ran in 3.95 s
# Operator `Gradient` ran in 3.53 s
# Operator `Gradient` ran in 3.69 s
#   0%|          | 0/5 [00:00<?, ?it/s]
# Training Epoch 0, Loss = 6.817668994351832e-06
# Training Epoch 1, Loss = 4.586059440850815e-06
# Training Epoch 2, Loss = 3.8922513625942135e-06
# Training Epoch 3, Loss = 3.3927373663576338e-06
# Training Epoch 4, Loss = 2.7201046504883583e-06
# Iteration 6: velocity loss = 0.0983934998512268
# /home/jovyan/work/devito_ta/simulation_born.py:111: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.18 s
# Operator `Forward` ran in 2.32 s
# Operator `Forward` ran in 2.28 s
# Operator `Forward` ran in 2.17 s
# Operator `Forward` ran in 3.74 s
# Operator `Gradient` ran in 2.86 s
# Operator `Gradient` ran in 3.14 s
# Operator `Gradient` ran in 3.16 s
# Operator `Gradient` ran in 2.79 s
# Operator `Gradient` ran in 4.53 s
# Operator `Forward` ran in 10.14 s
# Operator `Gradient` ran in 5.18 s
# ...
# 2025-10-13 20:51:51,598 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.06 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 2.10 s
# Operator `Forward` ran in 1.62 s
# Operator `Forward` ran in 4.44 s
# Operator `Gradient` ran in 3.25 s
# Operator `Forward` ran in 6.48 s
# Operator `Gradient` ran in 4.37 s
# Operator `Gradient` ran in 2.50 s
# Operator `Gradient` ran in 4.19 s
# Operator `Gradient` ran in 4.10 s
# Operator `Forward` ran in 13.88 s
# Operator `Gradient` ran in 4.63 s
# Operator `Forward` ran in 1.63 s
# Operator `Forward` ran in 1.71 s
# Operator `Forward` ran in 2.79 s
# Operator `Forward` ran in 1.95 s
# Operator `Forward` ran in 2.11 s
# Operator `Forward` ran in 2.02 s
# Operator `Gradient` ran in 2.46 s
# Operator `Gradient` ran in 3.84 s
# Operator `Gradient` ran in 2.75 s
# Operator `Gradient` ran in 2.87 s
# Operator `Gradient` ran in 3.30 s
# Operator `Gradient` ran in 3.02 s
# 2025-10-13 20:52:31,145 - distributed.worker.memory - WARNING - gc.collect() took 2.017s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-10-13 20:52:31,146 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 17.21 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 20:52:31,223 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 4.54 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.72 s
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 1.67 s
# Operator `Forward` ran in 1.93 s
# Operator `Forward` ran in 3.28 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 2.73 s
# Operator `Gradient` ran in 2.88 s
# Operator `Gradient` ran in 2.67 s
# Operator `Gradient` ran in 3.46 s
# Operator `Gradient` ran in 3.57 s
# Operator `Forward` ran in 1.72 s
# Operator `Forward` ran in 2.03 s
# Operator `Forward` ran in 1.79 s
# Operator `Forward` ran in 2.06 s
# Operator `Forward` ran in 2.16 s
# Operator `Forward` ran in 2.70 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 2.70 s
# Operator `Gradient` ran in 2.92 s
# Operator `Gradient` ran in 2.82 s
# Operator `Gradient` ran in 2.96 s
# Operator `Gradient` ran in 3.11 s
# Iteration 49: data loss = 2687.120849609375
# /home/jovyan/work/devito_ta/simulation_born.py:188: UserWarning: Sending large graph of size 11.85 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(born_x_shot, model_true,
# Operator `Forward` ran in 1.90 s
# Operator `Forward` ran in 2.06 s
# Operator `Forward` ran in 2.16 s
# Operator `Forward` ran in 2.26 s
# Operator `Forward` ran in 2.25 s
# Operator `Born` ran in 4.00 s
# Operator `Born` ran in 4.16 s
# Operator `Born` ran in 3.81 s
# Operator `Born` ran in 4.34 s
# Operator `Born` ran in 4.45 s
# Operator `Forward` ran in 9.79 s
# Operator `Gradient` ran in 3.33 s
# Operator `Gradient` ran in 3.21 s
# Operator `Gradient` ran in 3.18 s
# Operator `Gradient` ran in 6.32 s
# Operator `Gradient` ran in 5.51 s
# Operator `Born` ran in 3.75 s
# Operator `Gradient` ran in 5.67 s
# Operator `Forward` ran in 1.86 s
# Operator `Forward` ran in 1.97 s
# Operator `Forward` ran in 1.95 s
# Operator `Forward` ran in 2.13 s
# Operator `Forward` ran in 2.29 s
# Operator `Forward` ran in 2.46 s
# Operator `Born` ran in 3.62 s
# Operator `Born` ran in 3.89 s
# Operator `Born` ran in 3.89 s
# Operator `Born` ran in 3.70 s
# Operator `Born` ran in 4.00 s
# Operator `Born` ran in 4.27 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 3.13 s
# Operator `Gradient` ran in 3.23 s
# Operator `Gradient` ran in 3.80 s
# Operator `Gradient` ran in 7.02 s
# Operator `Gradient` ran in 6.88 s
# 2025-10-13 20:53:56,953 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.00 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.62 s
# Operator `Forward` ran in 1.63 s
# Operator `Forward` ran in 1.61 s
# Operator `Forward` ran in 1.90 s
# Operator `Forward` ran in 1.84 s
# Operator `Forward` ran in 2.70 s
# Operator `Born` ran in 3.55 s
# Operator `Born` ran in 3.62 s
# Operator `Born` ran in 3.93 s
# Operator `Born` ran in 4.09 s
# Operator `Born` ran in 3.70 s
# Operator `Born` ran in 4.38 s
# Operator `Gradient` ran in 3.18 s
# Operator `Gradient` ran in 2.96 s
# Operator `Gradient` ran in 3.37 s
# Operator `Gradient` ran in 3.08 s
# Operator `Gradient` ran in 3.94 s
# Operator `Gradient` ran in 3.96 s
# Operator `Forward` ran in 1.63 s
# Operator `Forward` ran in 1.88 s
# Operator `Forward` ran in 1.66 s
# Operator `Forward` ran in 1.82 s
# Operator `Forward` ran in 1.87 s
# Operator `Forward` ran in 3.09 s
# Operator `Born` ran in 3.79 s
# Operator `Born` ran in 3.70 s
# Operator `Born` ran in 3.91 s
# Operator `Born` ran in 3.98 s
# Operator `Born` ran in 4.31 s
# Operator `Born` ran in 4.62 s
# Operator `Gradient` ran in 2.77 s
# Operator `Gradient` ran in 3.36 s
# Operator `Gradient` ran in 3.06 s
# Operator `Gradient` ran in 3.31 s
# Operator `Gradient` ran in 4.21 s
# Operator `Gradient` ran in 5.55 s
# Operator `Forward` ran in 1.93 s
# Operator `Forward` ran in 1.72 s
# Operator `Forward` ran in 1.88 s
# Operator `Forward` ran in 2.44 s
# Operator `Forward` ran in 4.61 s
# Operator `Born` ran in 3.56 s
# Operator `Born` ran in 3.58 s
# Operator `Born` ran in 3.74 s
# Operator `Born` ran in 3.73 s
# Operator `Gradient` ran in 2.80 s
# Operator `Gradient` ran in 2.86 s
# Operator `Gradient` ran in 3.17 s
# Operator `Gradient` ran in 3.54 s
# Operator `Born` ran in 5.46 s
# Operator `Forward` ran in 12.92 s
# Operator `Gradient` ran in 5.49 s
# Operator `Born` ran in 3.79 s
# Operator `Gradient` ran in 5.45 s
#   0%|          | 0/5 [00:00<?, ?it/s]
# Training Epoch 0, Loss = 3.009696343736528e-07
# Training Epoch 1, Loss = 2.2829644708465885e-07
# Training Epoch 2, Loss = 2.2139223973093286e-07
# Training Epoch 3, Loss = 2.0584723180461493e-07
# Training Epoch 4, Loss = 1.8301825333060384e-07
# Iteration 50: velocity loss = 0.05639331415295601
# /home/jovyan/work/devito_ta/simulation_born.py:111: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.05 s
# Operator `Forward` ran in 2.08 s
# Operator `Forward` ran in 1.99 s
# Operator `Forward` ran in 2.10 s
# Operator `Forward` ran in 1.98 s
# Operator `Gradient` ran in 3.03 s
# Operator `Gradient` ran in 3.26 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 2.93 s
# Operator `Gradient` ran in 2.85 s
# Operator `Forward` ran in 11.11 s
# Operator `Gradient` ran in 5.27 s
# 2025-10-13 20:58:03,107 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.11 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 20:58:03,257 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.00 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 20:58:03,574 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.94 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 20:58:03,578 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.01 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 20:58:03,885 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.04 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 20:58:03,995 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.10 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.86 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 1.68 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 1.64 s
# Operator `Gradient` ran in 2.67 s
# Operator `Gradient` ran in 2.53 s
# Operator `Gradient` ran in 2.50 s
# Operator `Gradient` ran in 2.95 s
# Operator `Gradient` ran in 4.59 s
# Operator `Forward` ran in 8.42 s
# Operator `Gradient` ran in 3.67 s
# Operator `Forward` ran in 1.64 s
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 1.67 s
# Operator `Forward` ran in 1.66 s
# Operator `Forward` ran in 1.77 s
# Operator `Forward` ran in 2.83 s
# Operator `Gradient` ran in 2.52 s
# Operator `Gradient` ran in 2.70 s
# Operator `Gradient` ran in 2.75 s
# Operator `Gradient` ran in 3.08 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 3.04 s
# Operator `Forward` ran in 1.67 s
# Operator `Forward` ran in 2.49 s
# Operator `Forward` ran in 1.62 s
# Operator `Forward` ran in 1.85 s
# Operator `Forward` ran in 1.98 s
# Operator `Gradient` ran in 2.85 s
# Operator `Gradient` ran in 2.66 s
# Operator `Gradient` ran in 2.78 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 2.86 s
# Operator `Forward` ran in 10.29 s
# Operator `Gradient` ran in 5.49 s
# Operator `Forward` ran in 1.95 s
# Operator `Forward` ran in 2.12 s
# Operator `Forward` ran in 1.79 s
# Operator `Forward` ran in 1.86 s
# Operator `Forward` ran in 1.86 s
# Operator `Forward` ran in 3.33 s
# Operator `Gradient` ran in 2.84 s
# Operator `Gradient` ran in 2.86 s
# Operator `Gradient` ran in 3.08 s
# Operator `Gradient` ran in 3.31 s
# Operator `Gradient` ran in 4.03 s
# Operator `Gradient` ran in 3.05 s
# Iteration 50: data loss = 2615.32568359375
# /home/jovyan/work/devito_ta/simulation_born.py:188: UserWarning: Sending large graph of size 11.85 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(born_x_shot, model_true,
# Operator `Forward` ran in 2.12 s
# Operator `Forward` ran in 2.05 s
# Operator `Forward` ran in 2.07 s
# Operator `Born` ran in 3.64 s
# Operator `Born` ran in 3.73 s
# Operator `Born` ran in 4.07 s
# Operator `Forward` ran in 7.54 s
# Operator `Gradient` ran in 3.28 s
# Operator `Gradient` ran in 3.55 s
# Operator `Born` ran in 3.77 s
# Operator `Forward` ran in 13.10 s
# Operator `Gradient` ran in 5.67 s
# Operator `Forward` ran in 15.83 s
# Operator `Born` ran in 3.71 s
# Operator `Gradient` ran in 5.40 s
# Operator `Born` ran in 3.78 s
# Operator `Gradient` ran in 6.15 s
# Operator `Gradient` ran in 5.58 s
# Operator `Forward` ran in 1.81 s
# Operator `Forward` ran in 2.13 s
# Operator `Forward` ran in 1.81 s
# Operator `Forward` ran in 2.60 s
# Operator `Forward` ran in 2.70 s
# Operator `Forward` ran in 4.47 s
# Operator `Born` ran in 3.79 s
# Operator `Born` ran in 3.66 s
# Operator `Born` ran in 3.75 s
# Operator `Born` ran in 4.12 s
# Operator `Born` ran in 3.71 s
# Operator `Born` ran in 4.42 s
# Operator `Gradient` ran in 3.28 s
# Operator `Gradient` ran in 3.26 s
# Operator `Gradient` ran in 3.43 s
# Operator `Gradient` ran in 4.23 s
# Operator `Gradient` ran in 3.64 s
# Operator `Gradient` ran in 4.38 s
# 2025-10-13 21:00:19,960 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.95 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 21:00:20,152 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.98 GiB -- Worker memory limit: 21.33 GiB
# 2025-10-13 21:00:20,349 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.05 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.61 s
# Operator `Forward` ran in 1.63 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 1.87 s
# Operator `Forward` ran in 1.88 s
# Operator `Born` ran in 3.86 s
# Operator `Born` ran in 4.11 s
# Operator `Born` ran in 3.80 s
# Operator `Born` ran in 3.69 s
# Operator `Born` ran in 3.92 s
# Operator `Forward` ran in 8.56 s
# Operator `Gradient` ran in 2.81 s
# Operator `Gradient` ran in 2.95 s
# Operator `Gradient` ran in 3.04 s
# Operator `Gradient` ran in 2.93 s
# Operator `Gradient` ran in 3.37 s
# Operator `Born` ran in 3.95 s
# Operator `Gradient` ran in 5.41 s
# Operator `Forward` ran in 1.62 s
# Operator `Forward` ran in 2.07 s
# Operator `Forward` ran in 1.80 s
# Operator `Forward` ran in 2.00 s
# Operator `Forward` ran in 2.69 s
# Operator `Forward` ran in 3.26 s
# Operator `Born` ran in 3.72 s
# Operator `Born` ran in 3.69 s
# Operator `Born` ran in 4.45 s
# Operator `Born` ran in 3.78 s
# Operator `Born` ran in 4.29 s
# Operator `Born` ran in 3.74 s
# Operator `Gradient` ran in 3.41 s
# Operator `Gradient` ran in 2.92 s
# Operator `Gradient` ran in 3.15 s
# Operator `Gradient` ran in 3.06 s
# Operator `Gradient` ran in 4.74 s
# Operator `Gradient` ran in 9.85 s
# Operator `Forward` ran in 1.68 s
# Operator `Forward` ran in 1.84 s
# Operator `Forward` ran in 1.62 s
# Operator `Forward` ran in 1.62 s
# Operator `Forward` ran in 2.08 s
# Operator `Forward` ran in 2.79 s
# Operator `Born` ran in 3.85 s
# Operator `Born` ran in 4.58 s
# Operator `Born` ran in 3.65 s
# Operator `Born` ran in 3.66 s
# Operator `Born` ran in 4.53 s
# Operator `Born` ran in 3.70 s
# Operator `Gradient` ran in 3.27 s
# Operator `Gradient` ran in 2.88 s
# Operator `Gradient` ran in 3.02 s
# Operator `Gradient` ran in 3.12 s
# Operator `Gradient` ran in 3.28 s
# Operator `Gradient` ran in 4.00 s
#   0%|          | 0/5 [00:00<?, ?it/s]
# Training Epoch 0, Loss = 6.753197099777184e-07
# Training Epoch 1, Loss = 1.005657734895253e-07
# Training Epoch 2, Loss = 8.785959872568389e-08
# Training Epoch 3, Loss = 1.0078920756925782e-07
# Training Epoch 4, Loss = 2.5232296930202066e-07

# %%
dur = fnsh-strt
print(f'Running Duration for GN-Attention R2UNet: {((dur)/3600):.2f} hrs')
# Out:
# Running Duration for GN-Attention R2UNet: 5.33 hrs

# %%
print(network.down4)
print(network.ag1.conv_x)
# Out:
# Down_R2UNet(
#   (maxpool_conv): Sequential(
#     (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (1): R2Block(
#       (rec_conv_block): Sequential(
#         (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (input_conv): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (shortcut): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#   )
# )
# Conv2d(512, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
