# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
sys.path.append('/home/jovyan/work')
import os
os.environ["DASK_DISTRIBUTED__DIAGNOSTICS__NVML"] = "False"

import logging
import segyio
import numpy as np
import matplotlib.pyplot as plt
import time

from scipy.ndimage import gaussian_filter
from scipy.optimize import minimize
from scipy.signal import butter, sosfilt

from devito import *
from copy import deepcopy
from distributed import Client, wait, LocalCluster

from devito_ta.model_geom import get_model, get_geometry, grad_utils
from devito_ta.simulation import fm_multi_shots, grad_multi_shots
from devito_ta.plotting import plot_shotrecord_cust, plot_velocity_cust, plot_acquisition_geometry, plot_freq

configuration['log-level'] = 'WARNING'
configuration['opt'] = 'advanced'
logging.getLogger('distributed.nanny').setLevel(logging.ERROR)

# %%
file = 'vp_marmousi-ii_10m.segy'

with segyio.open(file, "r", ignore_geometry=True) as ss:
    n_traces = ss.tracecount
    sample_rate = segyio.tools.dt(ss) / 1000
    n_samples =ss.samples.size
    twt = ss.samples
    data = ss.trace.raw[:] 

#marm_file = '/Users/dzianddafi/Documents/TA/dataset/Marm.bin'
#v= np.fromfile(marm_file, dtype=np.float32).reshape((1220, 3840))

# %%
# Define water bottom depth in grid
wb = 50

# Define the model
v = data[200:1300, wb:].copy()             # Remove water layer

# Add water bottom to initial model
water_btm = np.ones((v.shape[0], wb)) * 1.5
v = np.concatenate([water_btm, v], axis=1)
minv = v.min()
maxv = v.max()

# Create initial model
init = gaussian_filter(v, sigma=[20, 20])  
init[:, :wb] = water_btm

init = np.clip(init, a_min=1.5, a_max=4.5)

# Get model

shape = (1100, 351)
spacing = (10, 10)
origin = (0, 0)

model1 = get_model(np.clip(v, 1.5, 5), shape, spacing, origin)
model0 = get_model(init, shape, spacing, origin)

# Plot velocity model
plot_velocity_cust(model1, colorbar=True, save=False, title='True Model', name='true_model')
plot_velocity_cust(model0, colorbar=True, save=False, title='Initial Model', name='init_model')

# %%
model1.critical_dt
# Out:
# np.float32(1.18)

# %%
# Create new geometry for 30 shots
par = {'nx':1100,          'dx':10,       'ox':0,
       'nz':351,          'dz':10,       'oz':0,
       'ns':30,           'ds':300,      'os':2020.0,  'sz':0,
       'nr':200,          'dr':10.0,     'or':0,       'rz':0,
       'nt':4000,         'dt':1.18,        'ot':0,       'nof':20,
       'freq':5,
      }

# Sampling frequency
fs = 1 / (par['dt']/1000)
nbl = model1.nbl

# Axes
x = np.arange(par['nx']) * par['dx'] + par['ox']
z = np.arange(par['nz']) * par['dz'] + par['oz']
t = np.arange(par['nt']) * par['dt'] + par['ot']
tmax = t[-1]

# Sources
x_s = np.zeros((par['ns'], 2))
x_s[:, 0] = np.arange(par['ns']) * par['ds'] + par['os']
x_s[:, 1] = par['sz'] 

# Receivers
x_r = np.zeros((par['nr'], 2))
x_r[:, 0] = np.arange(par['nr']) * par['dr'] + par['or']
x_r[:, 1] = par['rz'] 

geometry1 = get_geometry(model=model1,
                         src_x=x_s[:, 0],
                         src_z=x_s[:, 1],
                         rec_x=x_r[:, 0],
                         rec_z=x_r[:, 1],
                         t0=0,
                         tn=par['nt'],
                         nof=par['nof'],
                         src_type='Ricker',
                         f0=par['freq']/1000,
                         dt=par['dt'])


n_workers = 6

cluster = LocalCluster(
    n_workers=n_workers,
    memory_limit='auto',
    threads_per_worker=4,
    death_timeout=3600
)

client = Client(cluster)
client.restart()

# %%
#for i in [6, 14, -1]:
#    plot_velocity_cust(model1, source=geometry1[i].src_positions, receiver=geometry1[i].rec_positions, colorbar=True, save=False, title='True Model', name='true_model')

# %%
plot_acquisition_geometry(geometry1, 'Survey Design')

# %%
# Perform forward modelling at 5 Hz
dt = par['dt']

start_5hz = time.time()
fm = fm_multi_shots(model1, geometry1, n_workers, client, dt=dt)
finish_5hz = time.time()

duration_5hz = finish_5hz - start_5hz
print(f'Forward modelling duration for 30 shots: {(duration_5hz/60):.2f} minutes')
# Out:
# Operator `Forward` ran in 1.67 s
# Operator `Forward` ran in 1.67 s
# Operator `Forward` ran in 1.63 s
# Operator `Forward` ran in 1.63 s
# Operator `Forward` ran in 1.69 s
# Operator `Forward` ran in 1.64 s
# Operator `Forward` ran in 1.63 s
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 1.58 s
# Operator `Forward` ran in 1.66 s
# Operator `Forward` ran in 1.59 s
# Operator `Forward` ran in 1.86 s
# Operator `Forward` ran in 1.61 s
# Operator `Forward` ran in 1.61 s
# Operator `Forward` ran in 1.60 s
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 1.60 s
# Operator `Forward` ran in 1.72 s
# Operator `Forward` ran in 1.59 s
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 1.60 s
# Operator `Forward` ran in 1.67 s
# Operator `Forward` ran in 1.65 s
# Operator `Forward` ran in 1.70 s
# Operator `Forward` ran in 1.61 s
# Operator `Forward` ran in 1.66 s
# Operator `Forward` ran in 1.61 s
# Operator `Forward` ran in 1.61 s
# Operator `Forward` ran in 1.66 s
# Operator `Forward` ran in 1.61 s
# Forward modelling duration for 30 shots: 0.32 minutes

# %%
d_obs = [r for r, _ in fm]
plot_shotrecord_cust(d_obs[6].data, 'Shot Gather at Shot=7',
                     d_obs[14].data, 'Shot Gather at Shot=10',
                     d_obs[-4].data, 'Shot Gather at Shot=29',
                     model=model1,
                     t0=geometry1[0].t0,
                     tn=geometry1[0].tn,
                     save=False,
                     colorbar=True)

# %%
fpath = 'model_progress/marm_qn_1scale'

# Create wrapper
def loss_func(x, model_true, geoms, n_workers, client, d_true, blur, seis_loss):
    
    model_vp = x.reshape(model_true.shape)
    model_up = get_model(model_vp, shape, spacing, origin)
    
    client.restart()
    loss, grad = grad_multi_shots(model_true, model_up, geoms, n_workers, client, d_true, blur)
    seis_loss.append(loss)
    
    np.savetxt(f'{fpath}/loss_monitor.txt', seis_loss)
    np.savetxt(f'{fpath}/grad_monitor.txt', grad)
    return loss, grad.flatten().astype(np.float64)


# Callback to track model misfit
def fwi_callback(xk, fpath):

    update_vp = xk.reshape(model_true.shape)
    update_vp = np.clip(update_vp, minv, maxv)

    # Save first update and monitor model   
    first_model_path = f'{fpath}/first_model.txt'
    if not os.path.exists(first_model_path):
        np.savetxt(f'{fpath}/first_model.txt', update_vp)
    else:
        np.savetxt(f'{fpath}/model_monitor.txt', update_vp)

# %%
from scipy import optimize

# FWI with L-BFGS 

nbl = model1.nbl
model_true = model1
model_init = model0
geoms = geometry1.copy()
d_true = d_obs.copy()

vp_true = model1.vp.data[nbl:-nbl, nbl:-nbl]
seis_loss, vp_error = [], []
vp_tmp = [0, ]

ftol = 10e-10
gtol = 10e-10
maxiter = 50
maxls = 50
blur = 3

# Initial guess
v0 = model_init.vp.data[nbl:-nbl, nbl:-nbl]
m0 = v0.reshape(-1).astype(np.float64)

# Box contraints
vmin = v.min()   
vmax = v.max()
bounds = [(vmin, vmax) for _ in range(np.prod(model0.shape))]

start_inv = time.time()
client.restart()
res = optimize.minimize(loss_func, m0, 
                        args=(model_true, geoms, n_workers, client, d_true, blur, seis_loss), 
                        method='L-BFGS-B', 
                        jac=True, 
                        callback=lambda x: fwi_callback(x, fpath), 
                        bounds=bounds, 
                        options={'ftol':ftol,
                                 'maxls':maxls,
                                 'maxiter':maxiter, 
                                 'disp':True})
finish_inv = time.time()

# Store model, gradient, and misfit value
model_vp_optim1 = res.x.reshape(model1.shape)
np.savetxt(f'{fpath}/model_final.txt', model_vp_optim1)
model1_devito = get_model(model_vp_optim1, shape, spacing, origin)

grad_optim1 = res.jac.reshape(model1.shape)
np.savetxt(f'{fpath}/grad_final.txt', grad_optim1)
np.savetxt(f'{fpath}/misfit_final.txt', vp_error)

duration_inv = finish_inv - start_inv
# Out:
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.15 s
# Operator `Forward` ran in 2.08 s
# Operator `Forward` ran in 1.99 s
# Operator `Forward` ran in 2.47 s
# Operator `Gradient` ran in 3.11 s
# Operator `Forward` ran in 6.51 s
# Operator `Gradient` ran in 2.89 s
# Operator `Gradient` ran in 3.65 s
# Operator `Gradient` ran in 4.28 s
# Operator `Forward` ran in 11.62 s
# Operator `Gradient` ran in 4.68 s
# Operator `Gradient` ran in 5.60 s
# 2025-09-11 08:45:05,217 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.10 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:45:05,255 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.99 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:45:05,586 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.12 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:45:05,689 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.10 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:45:05,711 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.94 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:45:05,717 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.95 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 3.42 s
# Operator `Forward` ran in 3.72 s
# Operator `Forward` ran in 4.54 s
# Operator `Forward` ran in 4.57 s
# Operator `Gradient` ran in 2.72 s
# Operator `Gradient` ran in 3.30 s
# Operator `Gradient` ran in 4.12 s
# Operator `Forward` ran in 10.26 s
# Operator `Gradient` ran in 3.47 s
# Operator `Gradient` ran in 4.70 s
# Operator `Gradient` ran in 4.52 s
# Operator `Forward` ran in 1.77 s
# Operator `Forward` ran in 2.00 s
# Operator `Forward` ran in 2.49 s
# Operator `Forward` ran in 2.17 s
# Operator `Forward` ran in 1.84 s
# Operator `Forward` ran in 2.18 s
# Operator `Gradient` ran in 2.64 s
# Operator `Gradient` ran in 3.21 s
# Operator `Gradient` ran in 3.54 s
# Operator `Gradient` ran in 2.99 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 3.05 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 2.00 s
# Operator `Forward` ran in 1.81 s
# Operator `Forward` ran in 2.10 s
# Operator `Forward` ran in 2.10 s
# Operator `Gradient` ran in 2.64 s
# Operator `Gradient` ran in 2.64 s
# Operator `Gradient` ran in 2.77 s
# Operator `Gradient` ran in 2.85 s
# Operator `Gradient` ran in 2.95 s
# Operator `Gradient` ran in 3.06 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 1.83 s
# Operator `Forward` ran in 1.90 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 1.82 s
# Operator `Forward` ran in 1.95 s
# Operator `Gradient` ran in 2.89 s
# Operator `Gradient` ran in 2.86 s
# Operator `Gradient` ran in 2.79 s
# Operator `Gradient` ran in 2.94 s
# Operator `Gradient` ran in 2.99 s
# Operator `Gradient` ran in 2.83 s
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.18 s
# Operator `Forward` ran in 2.26 s
# Operator `Forward` ran in 2.19 s
# Operator `Forward` ran in 2.60 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 3.02 s
# Operator `Forward` ran in 5.98 s
# Operator `Gradient` ran in 3.60 s
# Operator `Gradient` ran in 6.11 s
# Operator `Gradient` ran in 11.76 s
# Operator `Forward` ran in 15.59 s
# Operator `Gradient` ran in 5.67 s
# 2025-09-11 08:46:42,670 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.99 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:46:42,692 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.00 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:46:42,725 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.96 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:46:43,135 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.02 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:46:43,224 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.10 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:46:43,268 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.10 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 2.19 s
# Operator `Forward` ran in 3.00 s
# Operator `Forward` ran in 3.59 s
# Operator `Forward` ran in 4.47 s
# Operator `Forward` ran in 4.45 s
# Operator `Gradient` ran in 2.89 s
# Operator `Gradient` ran in 3.10 s
# Operator `Forward` ran in 7.95 s
# Operator `Gradient` ran in 3.55 s
# Operator `Gradient` ran in 3.50 s
# Operator `Gradient` ran in 4.27 s
# Operator `Gradient` ran in 4.12 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 2.31 s
# Operator `Forward` ran in 3.93 s
# Operator `Forward` ran in 2.16 s
# Operator `Gradient` ran in 2.58 s
# Operator `Forward` ran in 4.50 s
# Operator `Gradient` ran in 2.60 s
# Operator `Gradient` ran in 3.52 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 3.95 s
# Operator `Gradient` ran in 3.85 s
# 2025-09-11 08:47:17,159 - distributed.worker.memory - WARNING - gc.collect() took 1.936s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-09-11 08:47:17,160 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 17.13 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:47:17,221 - distributed.worker.memory - WARNING - Worker is at 19% memory usage. Resuming worker. Process memory: 4.18 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.84 s
# Operator `Forward` ran in 1.85 s
# Operator `Forward` ran in 2.03 s
# Operator `Forward` ran in 2.17 s
# Operator `Forward` ran in 2.08 s
# Operator `Gradient` ran in 3.05 s
# Operator `Forward` ran in 4.43 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 2.94 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 3.41 s
# Operator `Forward` ran in 1.85 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 1.85 s
# Operator `Forward` ran in 2.01 s
# Operator `Forward` ran in 2.08 s
# Operator `Forward` ran in 2.09 s
# Operator `Gradient` ran in 2.85 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 2.80 s
# Operator `Gradient` ran in 3.49 s
# Operator `Gradient` ran in 3.00 s
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.17 s
# Operator `Forward` ran in 2.37 s
# Operator `Forward` ran in 2.47 s
# Operator `Gradient` ran in 3.02 s
# Operator `Forward` ran in 6.25 s
# Operator `Gradient` ran in 3.62 s
# Operator `Forward` ran in 9.11 s
# Operator `Gradient` ran in 3.57 s
# Operator `Forward` ran in 12.75 s
# Operator `Gradient` ran in 10.27 s
# Operator `Gradient` ran in 3.97 s
# Operator `Gradient` ran in 5.40 s
# 2025-09-11 08:48:19,054 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.97 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:48:19,298 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.10 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:48:19,678 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.99 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:48:19,694 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.07 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:48:19,762 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.09 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:48:19,923 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.98 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.81 s
# Operator `Forward` ran in 1.89 s
# Operator `Forward` ran in 1.80 s
# Operator `Forward` ran in 2.66 s
# Operator `Forward` ran in 4.63 s
# Operator `Gradient` ran in 3.65 s
# Operator `Gradient` ran in 3.61 s
# Operator `Gradient` ran in 3.28 s
# Operator `Gradient` ran in 7.10 s
# Operator `Gradient` ran in 3.85 s
# Operator `Forward` ran in 13.53 s
# Operator `Gradient` ran in 5.34 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 1.71 s
# Operator `Forward` ran in 1.77 s
# Operator `Forward` ran in 2.98 s
# Operator `Forward` ran in 4.41 s
# Operator `Gradient` ran in 2.70 s
# Operator `Gradient` ran in 2.59 s
# Operator `Gradient` ran in 3.04 s
# Operator `Gradient` ran in 3.06 s
# Operator `Gradient` ran in 3.74 s
# Operator `Gradient` ran in 2.66 s
# Operator `Forward` ran in 1.89 s
# Operator `Forward` ran in 2.09 s
# Operator `Forward` ran in 1.93 s
# Operator `Forward` ran in 2.47 s
# Operator `Forward` ran in 2.47 s
# Operator `Forward` ran in 3.17 s
# Operator `Gradient` ran in 2.90 s
# Operator `Gradient` ran in 2.96 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 3.14 s
# Operator `Gradient` ran in 3.12 s
# Operator `Gradient` ran in 3.25 s
# Operator `Forward` ran in 1.86 s
# Operator `Forward` ran in 1.87 s
# Operator `Forward` ran in 2.00 s
# Operator `Forward` ran in 2.24 s
# Operator `Forward` ran in 2.39 s
# Operator `Forward` ran in 2.32 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 2.98 s
# Operator `Gradient` ran in 3.09 s
# Operator `Gradient` ran in 3.10 s
# Operator `Gradient` ran in 3.28 s
# Operator `Gradient` ran in 5.08 s
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.13 s
# Operator `Forward` ran in 2.24 s
# Operator `Forward` ran in 2.20 s
# Operator `Forward` ran in 2.67 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 3.03 s
# Operator `Gradient` ran in 7.19 s
# Operator `Forward` ran in 12.53 s
# Operator `Forward` ran in 14.63 s
# Operator `Gradient` ran in 11.97 s
# Operator `Gradient` ran in 5.71 s
# Operator `Gradient` ran in 5.72 s
# 2025-09-11 08:50:04,293 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.97 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:50:04,417 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.95 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:50:04,618 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.07 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:50:04,806 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.06 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:50:04,838 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.08 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:50:04,841 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.06 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 2.92 s
# Operator `Forward` ran in 4.51 s
# Operator `Gradient` ran in 2.62 s
# Operator `Gradient` ran in 2.58 s
# Operator `Gradient` ran in 3.17 s
# Operator `Gradient` ran in 3.08 s
# Operator `Gradient` ran in 3.35 s
# Operator `Gradient` ran in 4.09 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 2.23 s
# Operator `Forward` ran in 2.35 s
# Operator `Gradient` ran in 2.61 s
# Operator `Gradient` ran in 2.59 s
# Operator `Gradient` ran in 2.55 s
# Operator `Gradient` ran in 3.35 s
# Operator `Gradient` ran in 3.31 s
# Operator `Forward` ran in 11.15 s
# Operator `Gradient` ran in 4.34 s
# 2025-09-11 08:50:42,504 - distributed.worker.memory - WARNING - gc.collect() took 1.861s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-09-11 08:50:42,507 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 17.09 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:50:42,539 - distributed.worker.memory - WARNING - Worker is at 19% memory usage. Resuming worker. Process memory: 4.12 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 2.25 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 2.03 s
# Operator `Forward` ran in 2.01 s
# Operator `Forward` ran in 2.78 s
# Operator `Forward` ran in 4.40 s
# Operator `Gradient` ran in 3.22 s
# Operator `Gradient` ran in 2.87 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 3.12 s
# Operator `Gradient` ran in 3.07 s
# Operator `Gradient` ran in 3.70 s
# Operator `Forward` ran in 2.04 s
# Operator `Forward` ran in 1.93 s
# Operator `Forward` ran in 2.15 s
# Operator `Forward` ran in 1.90 s
# Operator `Forward` ran in 1.99 s
# Operator `Forward` ran in 2.08 s
# Operator `Gradient` ran in 2.86 s
# Operator `Gradient` ran in 2.89 s
# Operator `Gradient` ran in 2.88 s
# Operator `Gradient` ran in 2.77 s
# Operator `Gradient` ran in 3.04 s
# Operator `Gradient` ran in 2.99 s
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.20 s
# Operator `Forward` ran in 2.26 s
# Operator `Forward` ran in 2.17 s
# Operator `Forward` ran in 2.12 s
# Operator `Forward` ran in 5.83 s
# Operator `Gradient` ran in 2.92 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 3.01 s
# Operator `Forward` ran in 8.39 s
# Operator `Gradient` ran in 4.21 s
# Operator `Gradient` ran in 5.51 s
# 2025-09-11 08:51:42,572 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.95 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:51:42,636 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.05 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:51:42,761 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.08 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:51:42,765 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.02 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:51:42,858 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.97 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:51:42,981 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.02 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.72 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 1.72 s
# Operator `Forward` ran in 2.17 s
# Operator `Forward` ran in 4.72 s
# Operator `Gradient` ran in 2.63 s
# Operator `Gradient` ran in 2.58 s
# Operator `Gradient` ran in 2.84 s
# Operator `Gradient` ran in 3.04 s
# Operator `Gradient` ran in 3.76 s
# Operator `Gradient` ran in 3.93 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 1.87 s
# Operator `Forward` ran in 2.35 s
# Operator `Forward` ran in 2.63 s
# Operator `Forward` ran in 1.82 s
# Operator `Gradient` ran in 2.63 s
# Operator `Gradient` ran in 3.01 s
# Operator `Gradient` ran in 2.85 s
# Operator `Gradient` ran in 3.14 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 3.22 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 2.08 s
# Operator `Forward` ran in 2.46 s
# Operator `Forward` ran in 1.98 s
# Operator `Forward` ran in 1.81 s
# Operator `Forward` ran in 2.85 s
# Operator `Gradient` ran in 2.61 s
# Operator `Gradient` ran in 2.93 s
# Operator `Gradient` ran in 2.86 s
# Operator `Gradient` ran in 2.96 s
# Operator `Gradient` ran in 3.20 s
# Operator `Gradient` ran in 3.17 s
# Operator `Forward` ran in 1.80 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 2.12 s
# Operator `Forward` ran in 2.06 s
# Operator `Forward` ran in 2.32 s
# Operator `Forward` ran in 2.25 s
# Operator `Gradient` ran in 2.83 s
# Operator `Gradient` ran in 3.02 s
# Operator `Gradient` ran in 3.08 s
# Operator `Gradient` ran in 2.96 s
# Operator `Gradient` ran in 2.95 s
# Operator `Gradient` ran in 3.32 s
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.19 s
# Operator `Forward` ran in 2.20 s
# Operator `Forward` ran in 2.17 s
# Operator `Forward` ran in 2.18 s
# Operator `Forward` ran in 2.71 s
# Operator `Gradient` ran in 3.06 s
# Operator `Gradient` ran in 3.26 s
# Operator `Gradient` ran in 3.61 s
# Operator `Gradient` ran in 3.19 s
# Operator `Gradient` ran in 3.24 s
# Operator `Forward` ran in 9.10 s
# Operator `Gradient` ran in 5.13 s
# 2025-09-11 08:53:09,604 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.09 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:53:09,617 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.97 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:53:09,860 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.97 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:53:10,117 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.07 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:53:10,136 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.10 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:53:10,152 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.95 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 3.81 s
# Operator `Forward` ran in 5.87 s
# Operator `Gradient` ran in 2.78 s
# Operator `Gradient` ran in 2.66 s
# Operator `Gradient` ran in 3.09 s
# Operator `Gradient` ran in 3.38 s
# Operator `Forward` ran in 9.29 s
# Operator `Gradient` ran in 3.70 s
# Operator `Gradient` ran in 4.07 s
# Operator `Forward` ran in 1.77 s
# Operator `Forward` ran in 1.93 s
# Operator `Forward` ran in 2.00 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 2.10 s
# Operator `Gradient` ran in 2.85 s
# Operator `Gradient` ran in 2.60 s
# Operator `Gradient` ran in 2.66 s
# Operator `Gradient` ran in 2.86 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 3.44 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 2.89 s
# Operator `Forward` ran in 1.90 s
# Operator `Forward` ran in 2.40 s
# Operator `Forward` ran in 1.93 s
# Operator `Forward` ran in 4.29 s
# Operator `Gradient` ran in 2.85 s
# Operator `Gradient` ran in 2.95 s
# Operator `Gradient` ran in 3.23 s
# Operator `Gradient` ran in 3.05 s
# Operator `Gradient` ran in 3.17 s
# Operator `Gradient` ran in 3.52 s
# Operator `Forward` ran in 1.92 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 2.02 s
# Operator `Forward` ran in 2.51 s
# Operator `Forward` ran in 2.14 s
# Operator `Forward` ran in 1.94 s
# Operator `Gradient` ran in 2.79 s
# Operator `Gradient` ran in 2.80 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 3.08 s
# Operator `Gradient` ran in 2.94 s
# Operator `Gradient` ran in 2.77 s
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.20 s
# Operator `Forward` ran in 2.23 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 3.02 s
# Operator `Forward` ran in 7.48 s
# Operator `Forward` ran in 11.98 s
# Operator `Gradient` ran in 4.78 s
# Operator `Forward` ran in 15.85 s
# Operator `Forward` ran in 16.26 s
# Operator `Gradient` ran in 5.68 s
# Operator `Gradient` ran in 5.58 s
# Operator `Gradient` ran in 5.65 s
# 2025-09-11 08:54:49,402 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.94 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:54:49,485 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.06 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:54:49,486 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.03 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:54:49,618 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.11 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:54:49,965 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.09 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:54:50,861 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.06 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 2.29 s
# Operator `Forward` ran in 2.76 s
# Operator `Forward` ran in 1.76 s
# Operator `Gradient` ran in 2.73 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 3.25 s
# Operator `Gradient` ran in 3.42 s
# Operator `Gradient` ran in 3.83 s
# Operator `Gradient` ran in 3.32 s
# Operator `Forward` ran in 1.81 s
# Operator `Forward` ran in 1.88 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 2.75 s
# Operator `Forward` ran in 4.78 s
# Operator `Forward` ran in 4.56 s
# Operator `Gradient` ran in 2.57 s
# Operator `Gradient` ran in 2.73 s
# Operator `Gradient` ran in 3.41 s
# Operator `Gradient` ran in 3.57 s
# Operator `Gradient` ran in 3.28 s
# Operator `Gradient` ran in 3.06 s
# Operator `Forward` ran in 2.18 s
# Operator `Forward` ran in 1.92 s
# Operator `Forward` ran in 2.22 s
# Operator `Forward` ran in 2.37 s
# Operator `Forward` ran in 2.19 s
# Operator `Forward` ran in 2.41 s
# Operator `Gradient` ran in 3.01 s
# Operator `Gradient` ran in 3.31 s
# Operator `Gradient` ran in 2.95 s
# Operator `Gradient` ran in 3.34 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 3.11 s
# Operator `Forward` ran in 1.71 s
# Operator `Forward` ran in 1.79 s
# Operator `Forward` ran in 1.81 s
# Operator `Forward` ran in 1.98 s
# Operator `Forward` ran in 2.27 s
# Operator `Forward` ran in 2.30 s
# Operator `Gradient` ran in 2.92 s
# Operator `Gradient` ran in 2.95 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 2.87 s
# Operator `Gradient` ran in 3.25 s
# Operator `Gradient` ran in 3.23 s
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.25 s
# Operator `Forward` ran in 2.23 s
# Operator `Forward` ran in 2.36 s
# Operator `Forward` ran in 2.17 s
# Operator `Forward` ran in 2.36 s
# Operator `Forward` ran in 2.67 s
# Operator `Gradient` ran in 3.01 s
# Operator `Gradient` ran in 3.17 s
# Operator `Gradient` ran in 3.34 s
# Operator `Gradient` ran in 3.30 s
# Operator `Gradient` ran in 4.35 s
# Operator `Gradient` ran in 10.45 s
# 2025-09-11 08:56:12,889 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.95 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:56:13,165 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.99 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:56:13,168 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.99 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:56:13,288 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.00 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:56:13,387 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.07 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:56:13,502 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.99 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 2.20 s
# Operator `Forward` ran in 4.48 s
# Operator `Forward` ran in 4.43 s
# Operator `Gradient` ran in 2.94 s
# Operator `Gradient` ran in 2.80 s
# Operator `Gradient` ran in 3.78 s
# Operator `Gradient` ran in 3.59 s
# Operator `Gradient` ran in 7.03 s
# Operator `Forward` ran in 13.86 s
# Operator `Gradient` ran in 5.40 s
# Operator `Forward` ran in 1.92 s
# Operator `Forward` ran in 1.77 s
# Operator `Forward` ran in 2.19 s
# Operator `Forward` ran in 2.02 s
# Operator `Forward` ran in 2.55 s
# Operator `Forward` ran in 2.78 s
# Operator `Gradient` ran in 2.75 s
# Operator `Gradient` ran in 2.96 s
# Operator `Gradient` ran in 3.62 s
# Operator `Gradient` ran in 3.63 s
# Operator `Gradient` ran in 3.65 s
# Operator `Gradient` ran in 4.14 s
# 2025-09-11 08:56:52,983 - distributed.worker.memory - WARNING - gc.collect() took 2.412s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-09-11 08:56:52,984 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 17.14 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:56:53,069 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 4.29 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.92 s
# Operator `Forward` ran in 2.10 s
# Operator `Forward` ran in 2.11 s
# Operator `Forward` ran in 1.94 s
# Operator `Forward` ran in 2.10 s
# Operator `Forward` ran in 2.11 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 2.98 s
# Operator `Gradient` ran in 2.98 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 3.06 s
# Operator `Forward` ran in 1.86 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 1.99 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 1.84 s
# Operator `Forward` ran in 1.88 s
# Operator `Gradient` ran in 2.89 s
# Operator `Gradient` ran in 2.88 s
# Operator `Gradient` ran in 2.80 s
# Operator `Gradient` ran in 2.89 s
# Operator `Gradient` ran in 3.01 s
# Operator `Gradient` ran in 2.96 s
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.22 s
# Operator `Forward` ran in 2.26 s
# Operator `Forward` ran in 2.21 s
# Operator `Forward` ran in 2.19 s
# Operator `Gradient` ran in 3.03 s
# Operator `Gradient` ran in 2.99 s
# Operator `Gradient` ran in 3.73 s
# Operator `Forward` ran in 11.71 s
# Operator `Gradient` ran in 10.80 s
# Operator `Forward` ran in 15.10 s
# Operator `Gradient` ran in 5.32 s
# Operator `Gradient` ran in 6.31 s
# 2025-09-11 08:57:57,488 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.05 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:57:57,510 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.01 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:57:57,580 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.09 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:57:57,668 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.01 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:57:57,982 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.94 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:57:57,990 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.98 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 1.77 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 2.21 s
# Operator `Forward` ran in 3.17 s
# Operator `Forward` ran in 4.41 s
# Operator `Gradient` ran in 2.61 s
# Operator `Gradient` ran in 2.96 s
# Operator `Gradient` ran in 3.62 s
# Operator `Gradient` ran in 3.43 s
# Operator `Gradient` ran in 3.25 s
# Operator `Gradient` ran in 4.61 s
# Operator `Forward` ran in 1.93 s
# Operator `Forward` ran in 1.88 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 2.05 s
# Operator `Forward` ran in 2.11 s
# Operator `Gradient` ran in 2.80 s
# Operator `Gradient` ran in 3.07 s
# Operator `Gradient` ran in 3.50 s
# Operator `Gradient` ran in 3.58 s
# Operator `Gradient` ran in 2.94 s
# Operator `Gradient` ran in 2.97 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 2.09 s
# Operator `Forward` ran in 2.08 s
# Operator `Forward` ran in 1.98 s
# Operator `Forward` ran in 2.12 s
# Operator `Forward` ran in 2.34 s
# Operator `Gradient` ran in 2.89 s
# Operator `Gradient` ran in 2.89 s
# Operator `Gradient` ran in 2.93 s
# Operator `Gradient` ran in 2.85 s
# Operator `Gradient` ran in 2.89 s
# Operator `Gradient` ran in 3.11 s
# Operator `Forward` ran in 1.84 s
# Operator `Forward` ran in 2.02 s
# Operator `Forward` ran in 1.96 s
# Operator `Forward` ran in 1.99 s
# Operator `Forward` ran in 2.43 s
# Operator `Forward` ran in 2.19 s
# Operator `Gradient` ran in 2.92 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 2.99 s
# Operator `Gradient` ran in 2.82 s
# Operator `Gradient` ran in 2.95 s
# Operator `Gradient` ran in 3.01 s
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.20 s
# Operator `Forward` ran in 2.19 s
# Operator `Forward` ran in 2.38 s
# Operator `Forward` ran in 2.39 s
# Operator `Gradient` ran in 2.94 s
# Operator `Gradient` ran in 3.09 s
# Operator `Gradient` ran in 3.38 s
# Operator `Gradient` ran in 3.20 s
# Operator `Forward` ran in 7.66 s
# Operator `Forward` ran in 13.61 s
# Operator `Gradient` ran in 4.86 s
# Operator `Gradient` ran in 6.20 s
# 2025-09-11 08:59:27,254 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.95 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:59:27,715 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.95 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:59:27,725 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.08 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:59:27,766 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.97 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:59:27,879 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.98 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 08:59:27,882 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.04 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 2.19 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 2.05 s
# Operator `Forward` ran in 4.45 s
# Operator `Gradient` ran in 4.03 s
# Operator `Gradient` ran in 3.32 s
# Operator `Gradient` ran in 3.85 s
# Operator `Gradient` ran in 3.20 s
# Operator `Gradient` ran in 7.41 s
# Operator `Forward` ran in 11.79 s
# Operator `Gradient` ran in 4.57 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 1.88 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 2.59 s
# Operator `Forward` ran in 2.08 s
# Operator `Gradient` ran in 2.62 s
# Operator `Gradient` ran in 2.62 s
# Operator `Gradient` ran in 2.64 s
# Operator `Gradient` ran in 3.92 s
# Operator `Gradient` ran in 3.37 s
# Operator `Gradient` ran in 6.67 s
# Operator `Forward` ran in 2.08 s
# Operator `Forward` ran in 1.85 s
# Operator `Forward` ran in 2.22 s
# Operator `Forward` ran in 2.08 s
# Operator `Forward` ran in 2.11 s
# Operator `Forward` ran in 2.31 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 2.84 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 2.87 s
# Operator `Gradient` ran in 3.06 s
# Operator `Gradient` ran in 3.19 s
# Operator `Forward` ran in 1.94 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 2.25 s
# Operator `Forward` ran in 1.82 s
# Operator `Forward` ran in 1.93 s
# Operator `Forward` ran in 2.11 s
# Operator `Gradient` ran in 2.71 s
# Operator `Gradient` ran in 2.80 s
# Operator `Gradient` ran in 2.82 s
# Operator `Gradient` ran in 2.95 s
# Operator `Gradient` ran in 3.22 s
# Operator `Gradient` ran in 3.24 s
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.20 s
# Operator `Forward` ran in 2.39 s
# Operator `Forward` ran in 2.42 s
# Operator `Forward` ran in 2.19 s
# Operator `Forward` ran in 2.39 s
# Operator `Forward` ran in 2.37 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 3.11 s
# Operator `Gradient` ran in 3.27 s
# Operator `Gradient` ran in 3.18 s
# ...
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 2.06 s
# Operator `Forward` ran in 2.24 s
# Operator `Forward` ran in 2.90 s
# Operator `Forward` ran in 3.73 s
# Operator `Gradient` ran in 2.94 s
# Operator `Gradient` ran in 2.78 s
# Operator `Gradient` ran in 3.68 s
# Operator `Gradient` ran in 5.30 s
# Operator `Gradient` ran in 3.81 s
# Operator `Gradient` ran in 3.45 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 2.13 s
# Operator `Forward` ran in 3.36 s
# Operator `Forward` ran in 1.94 s
# Operator `Forward` ran in 2.15 s
# Operator `Gradient` ran in 2.75 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 3.40 s
# Operator `Gradient` ran in 2.90 s
# Operator `Gradient` ran in 3.11 s
# Operator `Gradient` ran in 3.80 s
# 2025-09-11 10:05:58,382 - distributed.worker.memory - WARNING - gc.collect() took 2.676s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2025-09-11 10:05:58,383 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 17.14 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:05:58,402 - distributed.worker.memory - WARNING - Worker is at 23% memory usage. Resuming worker. Process memory: 5.11 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 2.40 s
# Operator `Forward` ran in 1.80 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 2.11 s
# Operator `Forward` ran in 2.30 s
# Operator `Gradient` ran in 2.92 s
# Operator `Gradient` ran in 3.27 s
# Operator `Gradient` ran in 2.71 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 3.14 s
# Operator `Gradient` ran in 3.11 s
# Operator `Forward` ran in 2.08 s
# Operator `Forward` ran in 2.12 s
# Operator `Forward` ran in 1.99 s
# Operator `Forward` ran in 2.22 s
# Operator `Forward` ran in 2.19 s
# Operator `Forward` ran in 2.08 s
# Operator `Gradient` ran in 2.86 s
# Operator `Gradient` ran in 2.88 s
# Operator `Gradient` ran in 2.93 s
# Operator `Gradient` ran in 3.10 s
# Operator `Gradient` ran in 3.07 s
# Operator `Gradient` ran in 2.99 s
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.11 s
# Operator `Forward` ran in 2.27 s
# Operator `Forward` ran in 2.18 s
# Operator `Forward` ran in 2.21 s
# Operator `Forward` ran in 2.69 s
# Operator `Gradient` ran in 3.02 s
# Operator `Gradient` ran in 3.05 s
# Operator `Gradient` ran in 2.98 s
# Operator `Gradient` ran in 3.16 s
# Operator `Forward` ran in 8.28 s
# Operator `Gradient` ran in 5.24 s
# Operator `Gradient` ran in 4.46 s
# 2025-09-11 10:06:53,634 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.95 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:06:53,713 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.05 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:06:53,744 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.05 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:06:53,771 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.03 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:06:53,903 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.95 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:06:54,091 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.04 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.77 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 2.29 s
# Operator `Forward` ran in 2.32 s
# Operator `Forward` ran in 4.44 s
# Operator `Gradient` ran in 2.79 s
# Operator `Gradient` ran in 3.42 s
# Operator `Gradient` ran in 4.27 s
# Operator `Gradient` ran in 3.12 s
# Operator `Gradient` ran in 3.73 s
# Operator `Gradient` ran in 8.59 s
# Operator `Forward` ran in 1.83 s
# Operator `Forward` ran in 2.14 s
# Operator `Forward` ran in 4.50 s
# Operator `Forward` ran in 4.79 s
# Operator `Forward` ran in 2.75 s
# Operator `Gradient` ran in 2.80 s
# Operator `Forward` ran in 4.17 s
# Operator `Gradient` ran in 3.12 s
# Operator `Gradient` ran in 3.24 s
# Operator `Gradient` ran in 3.10 s
# Operator `Gradient` ran in 3.60 s
# Operator `Gradient` ran in 3.74 s
# Operator `Forward` ran in 2.05 s
# Operator `Forward` ran in 2.09 s
# Operator `Forward` ran in 2.47 s
# Operator `Forward` ran in 2.09 s
# Operator `Forward` ran in 2.15 s
# Operator `Forward` ran in 3.33 s
# Operator `Gradient` ran in 2.90 s
# Operator `Gradient` ran in 2.93 s
# Operator `Gradient` ran in 2.96 s
# Operator `Gradient` ran in 3.08 s
# Operator `Gradient` ran in 3.11 s
# Operator `Gradient` ran in 3.28 s
# Operator `Forward` ran in 1.80 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 1.77 s
# Operator `Forward` ran in 2.00 s
# Operator `Forward` ran in 2.09 s
# Operator `Forward` ran in 2.16 s
# Operator `Gradient` ran in 2.97 s
# Operator `Gradient` ran in 2.99 s
# Operator `Gradient` ran in 3.09 s
# Operator `Gradient` ran in 3.06 s
# Operator `Gradient` ran in 3.02 s
# Operator `Gradient` ran in 3.07 s
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.37 s
# Operator `Forward` ran in 2.32 s
# Operator `Forward` ran in 2.17 s
# Operator `Forward` ran in 2.94 s
# Operator `Forward` ran in 2.19 s
# Operator `Gradient` ran in 2.96 s
# Operator `Gradient` ran in 3.33 s
# Operator `Gradient` ran in 3.26 s
# Operator `Gradient` ran in 3.07 s
# Operator `Forward` ran in 11.96 s
# Operator `Gradient` ran in 11.86 s
# Operator `Gradient` ran in 5.47 s
# 2025-09-11 10:08:28,680 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.97 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:08:28,702 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.04 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:08:29,092 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.11 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:08:29,116 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.04 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:08:29,132 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.96 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:08:29,133 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.04 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.77 s
# Operator `Forward` ran in 1.77 s
# Operator `Forward` ran in 1.77 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 2.21 s
# Operator `Forward` ran in 4.54 s
# Operator `Gradient` ran in 2.73 s
# Operator `Gradient` ran in 2.82 s
# Operator `Gradient` ran in 3.17 s
# Operator `Gradient` ran in 3.90 s
# Operator `Gradient` ran in 5.87 s
# Operator `Gradient` ran in 3.19 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 1.73 s
# Operator `Forward` ran in 2.43 s
# Operator `Gradient` ran in 2.64 s
# Operator `Gradient` ran in 2.60 s
# Operator `Gradient` ran in 2.63 s
# Operator `Gradient` ran in 3.06 s
# Operator `Gradient` ran in 3.56 s
# Operator `Gradient` ran in 3.47 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 2.13 s
# Operator `Forward` ran in 2.11 s
# Operator `Forward` ran in 1.87 s
# Operator `Forward` ran in 2.15 s
# Operator `Forward` ran in 1.89 s
# Operator `Gradient` ran in 2.87 s
# Operator `Gradient` ran in 2.98 s
# Operator `Gradient` ran in 2.96 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 2.85 s
# Operator `Gradient` ran in 2.92 s
# Operator `Forward` ran in 1.81 s
# Operator `Forward` ran in 1.71 s
# Operator `Forward` ran in 1.91 s
# Operator `Forward` ran in 1.74 s
# Operator `Forward` ran in 1.90 s
# Operator `Forward` ran in 2.05 s
# Operator `Gradient` ran in 2.89 s
# Operator `Gradient` ran in 2.88 s
# Operator `Gradient` ran in 2.75 s
# Operator `Gradient` ran in 2.76 s
# Operator `Gradient` ran in 2.85 s
# Operator `Gradient` ran in 2.98 s
# /home/jovyan/work/devito_ta/simulation.py:107: UserWarning: Sending large graph of size 12.10 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   futures.append(client.submit(grad_x_shot,
# Operator `Forward` ran in 2.37 s
# Operator `Forward` ran in 2.18 s
# Operator `Forward` ran in 2.47 s
# Operator `Forward` ran in 2.26 s
# Operator `Forward` ran in 2.19 s
# Operator `Forward` ran in 4.46 s
# Operator `Gradient` ran in 2.94 s
# Operator `Gradient` ran in 2.98 s
# Operator `Gradient` ran in 3.76 s
# Operator `Gradient` ran in 4.82 s
# Operator `Gradient` ran in 3.21 s
# Operator `Gradient` ran in 5.77 s
# 2025-09-11 10:09:46,646 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.01 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:09:46,739 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.01 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:09:46,756 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.96 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:09:47,036 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.99 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:09:47,137 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 14.94 GiB -- Worker memory limit: 21.33 GiB
# 2025-09-11 10:09:48,014 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 15.11 GiB -- Worker memory limit: 21.33 GiB
# Operator `Forward` ran in 1.80 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 2.18 s
# Operator `Forward` ran in 1.78 s
# Operator `Forward` ran in 4.54 s
# Operator `Forward` ran in 4.49 s
# Operator `Gradient` ran in 2.64 s
# Operator `Gradient` ran in 2.64 s
# Operator `Gradient` ran in 3.82 s
# Operator `Gradient` ran in 4.05 s
# Operator `Gradient` ran in 3.81 s
# Operator `Gradient` ran in 3.76 s
# Operator `Forward` ran in 1.79 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 1.75 s
# Operator `Forward` ran in 2.17 s
# Operator `Forward` ran in 2.15 s
# Operator `Forward` ran in 2.77 s
# Operator `Gradient` ran in 2.72 s
# Operator `Gradient` ran in 2.66 s
# Operator `Gradient` ran in 3.00 s
# Operator `Gradient` ran in 3.01 s
# Operator `Gradient` ran in 3.55 s
# Operator `Gradient` ran in 6.00 s
# Operator `Forward` ran in 1.76 s
# Operator `Forward` ran in 2.51 s
# Operator `Forward` ran in 2.10 s
# Operator `Forward` ran in 2.70 s
# Operator `Forward` ran in 2.02 s
# Operator `Forward` ran in 2.19 s
# Operator `Gradient` ran in 2.91 s
# Operator `Gradient` ran in 2.92 s
# Operator `Gradient` ran in 2.92 s
# Operator `Gradient` ran in 3.31 s
# Operator `Gradient` ran in 2.96 s
# Operator `Gradient` ran in 3.21 s
# Operator `Forward` ran in 1.83 s
# Operator `Forward` ran in 2.03 s
# Operator `Forward` ran in 2.05 s
# Operator `Forward` ran in 2.06 s
# Operator `Forward` ran in 2.06 s
# Operator `Forward` ran in 1.98 s
# Operator `Gradient` ran in 2.99 s
# Operator `Gradient` ran in 3.15 s
# Operator `Gradient` ran in 2.84 s
# Operator `Gradient` ran in 3.01 s
# Operator `Gradient` ran in 2.90 s
# Operator `Gradient` ran in 2.94 s

# %%
print(f'Duration for inversion with L-BFGS: {(duration_inv/3600):.2f} hrs')
# Out:
# Duration for inversion with L-BFGS: 1.44 hrs
